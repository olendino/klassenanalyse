# %%
service_worker = {

    "Hilfsarbeitskräfte, anderweitig nicht genannt",
    "Zählerableser, Automatenbefüller und -kassierer",
    "Boten, Paketauslieferer und Gepäckträger",
    "Straßenkehrer und verwandte Berufe",
    "Auf der Straße arbeitende Dienstleistungskräfte und verwandte Berufe",
    "Regalbetreuer und -auffüller",
    "Sonstiges Reinigungspersonal",
    "Fensterputzer",
    "Reinigungspersonal und Hilfskräfte in Privathaushalten",
    "Reinigungspersonal und Hilfskräfte in Büros, Hotels und anderen Einrichtungen",
    "Handwäscher und Handbügler",
    "Fahrzeugreiniger",
    "Personenkraftwagen-, Taxi-, Kleintransporter- und Kleinbusfahrer",
    "Busfahrer und Straßenbahnführer",
    "Kammerjäger und andere Schädlingsbekämpfungsberufe",
    "Produkttester und -klassierer (ohne Nahrungsmittel und Getränke)",
    "Taucher",
    "Nahrungsmittel- und Getränkekoster und -klassierer",
    "Fassadenreiniger und Schornsteinfeger/Rauchfangkehrer",
    "Sicherheitswachpersonal",
    "Betreuungsberufe im Gesundheitswesen, anderweitig nicht genannt",
    "Kassierer und Kartenverkäufer",
    "Verkäufer und Verkaufshilfskräfte in Handelsgeschäften",
    "Mannequins/Dressmen und sonstige Modelle",
    "Produktvorführer",
    "Telefonverkäufer",
    "Tankwarte",
    "Imbissverkäufer",
    "Verkaufskräfte, anderweitig nicht genannt",
    "Kinderbetreuer",
    "Lernbetreuer",
    "Pflegehelfer",
    "Haus- und Familienpfleger",
    "Kellner",
    "Barkeeper",
    "Friseure",
    "Kosmetiker und verwandte Berufe",
    "Hauswirtschafter in Privathaushalten",
    "Hauswarte",
    "Astrologen, Wahrsager und verwandte Berufe",
    "Bestatter und Einbalsamierer",
    "Tierpfleger und -betreuer",
    "Fahrschullehrer",
    "Berufe im Bereich personenbezogener Dienstleistungen, anderweitig nicht genannt",
    "Verkaufsstand- und Marktverkäufer",
    "Gelegenheitsarbeiter"
}
# Convert to dictionary with the same value for all keys
dienstleistungsarbeiter = {key: "Dienstleistungsarbeiter" for key in service_worker}

# Display the resulting dictionary
print(dienstleistungsarbeiter)
# Out:
# {'Imbissverkäufer': 'Dienstleistungsarbeiter', 'Sicherheitswachpersonal': 'Dienstleistungsarbeiter', 'Kinderbetreuer': 'Dienstleistungsarbeiter', 'Fahrschullehrer': 'Dienstleistungsarbeiter', 'Kammerjäger und andere Schädlingsbekämpfungsberufe': 'Dienstleistungsarbeiter', 'Barkeeper': 'Dienstleistungsarbeiter', 'Zählerableser, Automatenbefüller und -kassierer': 'Dienstleistungsarbeiter', 'Produkttester und -klassierer (ohne Nahrungsmittel und Getränke)': 'Dienstleistungsarbeiter', 'Friseure': 'Dienstleistungsarbeiter', 'Fahrzeugreiniger': 'Dienstleistungsarbeiter', 'Handwäscher und Handbügler': 'Dienstleistungsarbeiter', 'Verkaufskräfte, anderweitig nicht genannt': 'Dienstleistungsarbeiter', 'Telefonverkäufer': 'Dienstleistungsarbeiter', 'Reinigungspersonal und Hilfskräfte in Privathaushalten': 'Dienst
fachkräfte bei staatlichen Pass-, Lizenz- und Genehmigungsstellen",
    "Polizeikommissare und Kriminalbeamte",
    "Fachkräfte in der öffentlichen Verwaltung, anderweitig nicht genannt",
    "Universitäts- und Hochschullehrer",
    "Lehrkräfte im Bereich Berufsbildung",
    "Lehrkräfte im Sekundarbereich",
    "Lehrkräfte im Primarbereich",
    "Lehrkräfte und Erzieher im Vorschulbereich",
    "Pädagogik- und Didaktikspezialisten",
    "Lehrkräfte im Bereich Sonderpädagogik",
    "Sonstige Sprachlehrer",
    "Sonstige Musiklehrer",
    "Sonstige Kunstlehrer",
    "Richter",
    "Juristen, anderweitig nicht genannt",
    'Offiziere in regulären Streitkräften',
    'Unteroffiziere in regulären Streitkräften',
    'Angehörige der regulären Streitkräfte in sonstigen Rängen'
}

# Convert to dictionary with the same value for all keys
beamte = {key: "Staatsdiener" for key in beamte}

# Display the resulting dictionary
print(type(beamte))
# Out:
# <class 'dict'>

# %% [markdown]
# ## Managers and super visors:
#
# ISCO-08 P. 40:
# The critical difference is that supervisors are responsible only for supervision of the activities of other workers whereas those classified in Major Group 1: Managers have overall responsibility for the operations of a business or organizational unit.

# %%
anleitender_beschäftigter={
    'Leiter eines Einzelhandelsgeschäftes',
    'Reinigungs- und Hauswirtschaftsleiter in Büros, Hotels und anderen Einrichtungen',
    'Verkaufsaufsichtskräfte in Handelsgeschäften',
    'Sekretariatsleiter',
    'Berufsberater und -analytiker und akademische und vergleichbare Personalfachleute'
    'Fachkräfte in Personalschulung und -entwicklung',
    "Produktionsleiter im Bergbau",
    "Produktionsleiter bei der Herstellung von Waren",
    "Bauleiter",
    'Schiffsführer, nautische Schiffsoffiziere und Schiffslotsen',
    'Flugzeugführer und verwandte Berufe'
}
# Convert to dictionary with the same value for all keys
anleitender_beschäftigter = {key: "Anleitender Beschäftigter" for key in anleitender_beschäftigter}

# Display the resulting dictionary
print(anleitender_beschäftigter)
# Out:
# {'Verkaufsaufsichtskräfte in Handelsgeschäften': 'Anleitender Beschäftigter', 'Sekretariatsleiter': 'Anleitender Beschäftigter', 'Leiter eines Einzelhandelsgeschäftes': 'Anleitender Beschäftigter', 'Flugzeugführer und verwandte Berufe': 'Anleitender Beschäftigter', 'Berufsberater und -analytiker und akademische und vergleichbare PersonalfachleuteFachkräfte in Personalschulung und -entwicklung': 'Anleitender Beschäftigter', 'Bauleiter': 'Anleitender Beschäftigter', 'Reinigungs- und Hauswirtschaftsleiter in Büros, Hotels und anderen Einrichtungen': 'Anleitender Beschäftigter', 'Schiffsführer, nautische Schiffsoffiziere und Schiffslotsen': 'Anleitender Beschäftigter', 'Produktionsleiter im Bergbau': 'Anleitender Beschäftigter', 'Produktionsleiter bei der Herstellung von Waren': 'Anleitender Beschäftigter'}

# %%
,
'Sekretariatsfachkräfte in Verwaltung und Geschäftsleitung' #gericht aber auch persönlicher assitent
# Out:
# 'Sekretariatsfachkräfte in Verwaltung und Geschäftsleitung'

# %%
industrie_arbeiter={
    'Arbeiter in der Abfallsortierung',
    'Arbeiter in der Abfall- und Wertstoffsammlung',
    'Küchenhilfen',
    'Zubereiter von Fast Food und anderen Imbissen',
    'Frachtarbeiter und verwandte Berufe',
    'Hilfsarbeiter bei der Herstellung von Waren, anderweitig nicht genannt',
    'Verpacker',
    "Hilfsarbeiter im Ackerbau",
    "Hilfsarbeiter in der Tierhaltung",
    "Hilfsarbeiter in Ackerbau und Tierhaltung (ohne ausgeprägten Schwerpunkt)",
    "Hilfsarbeiter im Gartenbau",
    "Hilfsarbeiter in der Forstwirtschaft",
    "Hilfsarbeiter in der Fischerei und Aquakultur",
    "Hilfsarbeiter im Bergbau und in der Gewinnung von Steinen und Erden",
    "Hilfsarbeiter im Tiefbau",
    "Hilfsarbeiter im Hochbau"
    "Fahrer schwerer Lastkraftwagen",
    "Führer von mobilen land- und forstwirtschaftlichen Maschinen",
    "Führer von Erdbewegungs- und verwandten Maschinen",
    "Kranführer, Aufzugmaschinisten und Bediener verwandter Hebeeinrichtungen",
    "Gabelstaplerfahrer und verwandte Berufe",
    "Deckspersonal auf Schiffen und verwandte Berufe",
    'Bediener von Sicherungs-, Signal- und Leittechnik im Schienennetzbetrieb',
     "Handwerks- und verwandte Berufe, anderweitig nicht genannt",
    "Bergleute und Grubenarbeiter",
    "Bediener von Mineral- und Gesteinsaufbereitungsanlagen",
    "Tiefbohrer und verwandte Berufe",
    "Bediener von Maschinen zur Herstellung und Verarbeitung von Zement, Steinen und sonstigen Mineralien",
    "Bediener von Anlagen in der Metallerzeugung und -umformung",
    "Bediener von Anlagen zur Metallveredlung, Plattierung und Beschichtung von Metallen",
    "Bediener von Anlagen und Maschinen für chemische Erzeugnisse",
    "Bediener von Anlagen für fotografische Erzeugnisse",
    "Bediener von Maschinen zur Herstellung von Gummiwaren",
    "Bediener von Maschinen zur Herstellung von Kunststoffwaren",
    "Bediener von Maschinen zur Herstellung von Papierwaren",
    "Bediener von Spinnstoffaufbereitungs-, Spinn- und Spulmaschinen",
    "Bediener von Web-, Strick- und Wirkmaschinen",
    "Bediener von Nähmaschinen",
    "Bediener von Bleich- und Färbemaschinen",
    "Bediener von Pelz- und Lederzurichtungs- und -vorbereitungsmaschinen",
    "Bediener von Maschinen zur Schuhherstellung und verwandte Berufe",
    "Bediener von Wäschereimaschinen",
    "Bediener von Maschinen zur Herstellung von Textil-, Pelz- und Lederwaren, anderweitig nicht genannt",
    "Bediener von Maschinen zur Herstellung von Nahrungs- und Genussmitteln",
    "Bediener von Anlagen zur Zellstoff- und Papierherstellung",
    "Bediener von Anlagen zur Holzaufbereitung",
    "Bediener von Anlagen zur Glas- und Keramikherstellung",
    "Bediener von Dampfmaschinen und -kesseln",
    "Bediener von Verpackungs-, Abfüll- und Etikettiermaschinen",
    "Bediener stationärer Anlagen und Maschinen, anderweitig nicht genannt",
    "Berufe der Montage von mechanischen Bauteilen",
    "Berufe der Montage von elektrischen und elektronischen Geräten",
    "Montageberufe, anderweitig nicht genannt",
    "Holztrockner und -konservierer",
    "Möbeltischler und verwandte Berufe",
    "Einrichter und Bediener von Holzbearbeitungsmaschinen",
    "Herren- und Damenschneider, Kürschner und Hutmacher",
    "Schnittmustermacher und Zuschneider",
    "Näher, Sticker und verwandte Berufe",
    "Polsterer und verwandte Berufe",
    "Pelzveredler, Gerber und Fellzurichter",
    "Schuhmacher und verwandte Berufe",
    "Tabakaufbereiter und Tabakwarenmacher",
    'Obst- und Gemüsekonservierer und verwandte Berufe',
    'Molkerei- und Käsereifachkräfte',
    'Bäcker, Konditoren und Konfektmacher',
    'Fleischer, Fischhändler und -verarbeiter und verwandte Berufe',
    'Installateure und Servicetechniker im Bereich Informations- und Kommunikationstechnik',
    "Former und Kernmacher (für Metallguss)",
    "Schweißer und Brennschneider",
    "Blechkaltverformer",
    "Baumetallverformer und Metallbauer",
    "Verspannungsmonteure und Seilspleißer",
    "Grobschmiede, Hammerschmiede und Schmiedepresser",
    "Werkzeugmechaniker und verwandte Berufe",
    "Werkzeugmaschineneinrichter und -bediener",
    "Metallpolierer, Rundschleifer und Werkzeugschärfer",
    "Kraftfahrzeugmechaniker und -schlosser",
    "Flugmotorenmechaniker und -schlosser",
    "Landmaschinen- und Industriemaschinenmechaniker und -schlosser",
    "Fahrradmechaniker und verwandte Berufe",
    "Präzisionsinstrumentenmacher und -instandsetzer",
    "Musikinstrumentenbauer und -stimmer",
    "Schmuckwarenhersteller und Edelmetallbearbeiter",
    "Keramiker und verwandte Berufe",
    "Glasmacher, -schneider, -schleifer und -veredler",
    "Schildermaler, Dekormaler, Graveure und Ätzer",
    "Kunsthandwerkliche Berufe für Holz, Korbwaren und verwandte Materialien",
    "Kunsthandwerkliche Berufe für Textilien, Leder und verwandte Materialien",
    "Kunsthandwerkliche Berufe, anderweitig nicht genannt",
    "Techniker in der Druckvorstufe",
    "Drucker",
    "Berufe in der Druckweiterverarbeitung und Buchbinder",
    "Bauelektriker und verwandte Berufe",
    "Elektromechaniker und verwandte Berufe",
    "Elektroleitungsinstallateure und Wartungspersonal",
    "Elektroniker und Elektronik-Servicetechniker",
    "Ackerbauern und Gemüseanbauer",
    "Baum- und Strauchfrüchteanbauer",
    "Gärtner, Saat- und Pflanzenzüchter",
    "Nutztierhalter (ohne Geflügel) und Milchproduzenten",
    "Geflügelhalter",
    "Imker und Seidenraupenzüchter",
    "Tierhalter, anderweitig nicht genannt",
    "Landwirte mit Ackerbau und Tierhaltung (ohne ausgeprägten Schwerpunkt)",
    "Forstarbeitskräfte und verwandte Berufe",
    "Fachkräfte im Bereich Aquakultur",
    "Binnen- und Küstenfischer",
    "Hochseefischer",
    "Rohbaufacharbeiter im Hochbau",
    "Maurer und verwandte Berufe",
    "Steinmetze, Steinspalter, -bearbeiter und Steinbildhauer",
    "Betonierer, Betonoberflächenfertiger und verwandte Berufe",
    "Zimmerleute und Bautischler",
    "Baukonstruktions- und verwandte Berufe, anderweitig nicht genannt",
    "Dachdecker",
    "Boden- und Fliesenleger",
    "Stuckateure",
    "Isolierer",
    "Glaser",
    "Bauspengler und Sanitär- und Heizungsinstallateure",
    "Klima- und Kälteanlagenbauer",
    "Maler und verwandte Berufe",
    "Lackierer und verwandte Berufe",
    "Köche",
    "Fachkräfte in der Lagerwirtschaft",
    'Führer von Fahrzeugen und Maschinen mit Zugtierantrieb',
    'Führer von Handwagen und pedalbetriebenen Fahrzeugen',
    'Sprengmeister und Sprengbeauftragte'
Industriearbeiter', 'Bediener von Mineral- und Gesteinsaufbereitungsanlagen': 'Industriearbeiter', 'Ackerbauern und Gemüseanbauer': 'Industriearbeiter', 'Bediener von Anlagen zur Zellstoff- und Papierherstellung': 'Industriearbeiter', 'Bediener von Pelz- und Lederzurichtungs- und -vorbereitungsmaschinen': 'Industriearbeiter', 'Werkzeugmaschineneinrichter und -bediener': 'Industriearbeiter', 'Präzisionsinstrumentenmacher und -instandsetzer': 'Industriearbeiter', 'Baukonstruktions- und verwandte Berufe, anderweitig nicht genannt': 'Industriearbeiter', 'Hilfsarbeiter im Ackerbau': 'Industriearbeiter', 'Herren- und Damenschneider, Kürschner und Hutmacher': 'Industriearbeiter', 'Führer von Erdbewegungs- und verwandten Maschinen': 'Industriearbeiter', 'Bediener von Verpackungs-, Abfüll- und Etikettiermaschinen': 'Industriearbeiter', 'Drucker': 'Industriearbeiter', 'Fleischer, Fischhändler und -verarbeiter und verwandte Berufe': 'Industriearbeiter', 'Installateure und Servicetechniker im Bereich Informations- und Kommunikationstechnik': 'Industriearbeiter', 'Bediener von Maschinen zur Herstellung von Gummiwaren': 'Industriearbeiter', 'Kranführer, Aufzugmaschinisten und Bediener verwandter Hebeeinrichtungen': 'Indus ...

# %%
Hochspezialisierte_Beschäftigte = {
    "Physiker und Astronomen",
    "Meteorologen",
    "Chemiker",
    "Geologen und Geophysiker",
    "Mathematiker, Versicherungsmathematiker und Statistiker",
    "Biologen, Botaniker, Zoologen und verwandte Berufe",
    "Agrar-, Forst- und Fischereiwissenschaftler und -berater",
    "Umweltwissenschaftler",
    "Wirtschafts- und Produktionsingenieure",
    "Bauingenieure",
    "Umweltschutzingenieure",
    "Maschinenbauingenieure",
    "Chemieingenieure",
    "Bergbauingenieure, Metallurgen und verwandte Berufe",
    "Ingenieure, anderweitig nicht genannt",
    "Ingenieure im Bereich Elektrotechnik",
    "Ingenieure im Bereich Elektronik",
    "Ingenieure im Bereich Telekommunikationstechnik",
    "Architekten",
    "Landschaftsarchitekten",
    "Produkt- und Textildesigner",
    "Raum-, Stadt- und Verkehrsplaner",
    "Kartografen und Vermessungsingenieure",
    "Grafik- und Multimediadesigner",
    "Akademische und vergleichbare Krankenpflegefachkräfte",
    "Akademische und vergleichbare Geburtshilfefachkräfte",
    "Akademische und vergleichbare Fachkräfte in der traditionellen und komplementären Medizin",
    "Feldscher und vergleichbare paramedizinische Praktiker",
    "Tierärzte",
    "Zahnärzte",
    "Apotheker",
    "Akademische und vergleichbare Fachkräfte in den Bereichen Umwelt- und Arbeitsmedizin sowie Hygiene",
    "Physiotherapeuten",
    "Diätologen und Ernährungsberater",
    "Audiologen und Sprachtherapeuten",
    "Optometristen und Orthoptisten",
    "Akademische und verwandte Gesundheitsberufe, anderweitig nicht genannt",
    "Ausbilder im Bereich Informationstechnologie",
    "Lehrkräfte, anderweitig nicht genannt",
    "Wirtschaftsprüfer, Steuerberater und verwandte Berufe",
    "Finanz- und Anlageberater",
    "Finanzanalysten",
    "Akademische und vergleichbare Fachkräfte im Bereich Management- und Organisationsanalyse",
    "Akademische und vergleichbare Fachkräfte in der strategischen Planung in Politik und Wirtschaft",
    "Berufsberater und -analytiker und akademische und vergleichbare Personalfachleute",
    "Fachkräfte in Personalschulung und -entwicklung",
    "Akademische und vergleichbare Fachkräfte in Werbung und Marketing",
    "Akademische und vergleichbare Fachkräfte in der Öffentlichkeitsarbeit",
    "Akademische und vergleichbare Fachkräfte im Bereich Vertrieb (Technik und Medizin, ohne Informations- und Kommunikationstechnologie)",
    "Akademische und vergleichbare Fachkräfte im Vertrieb von Informations- und Kommunikationstechnologie",
    "Systemanalytiker",
    "Softwareentwickler",
    "Web- und Multimediaentwickler",
    "Anwendungsprogrammierer",
    "Entwickler und Analytiker von Software und Anwendungen, anderweitig nicht genannt",
    "Datenbankentwickler und -administratoren",
    "Systemadministratoren",
    "Akademische und vergleichbare Fachkräfte für Computernetzwerke",
    "Akademische und vergleichbare Fachkräfte für Datenbanken und Netzwerke, anderweitig nicht genannt",
    "Archiv- und Museumswissenschaftler",
    "Bibliothekswissenschaftler und verwandte Informationswissenschaftler",
    "Volkswirtschaftler",
    "Soziologen, Anthropologen und verwandte Wissenschaftler",
    "Philosophen, Historiker und Politologen",
    "Sozialarbeiter",
    "Geistliche, Seelsorger",
    "Journalisten",
    "Übersetzer, Dolmetscher und andere Linguisten",
    "Regisseure und Produzenten im Film- und Bühnenbereich sowie in verwandten Bereichen",
    "Schauspieler",
    "Sprecher im Rundfunk, Fernsehen und sonstigen Medien",
    "Bildende und darstellende Künstler, anderweitig nicht genannt",
    "Chemo- und Physikotechniker",
    "Bautechniker",
    "Elektrotechniker",
    "Techniker im Bereich Elektronik",
    "Maschinenbautechniker",
    "Chemiebetriebs- und Verfahrenstechniker",
    "Bergbau- und Hüttentechniker",
    "Technische Zeichner",
    "Material- und ingenieurtechnische Fachkräfte, anderweitig nicht genannt",
    "Steuerer von Energieerzeugungsanlagen",
    "Steuerer von Verbrennungs- und Wasserbehandlungsanlagen",
    "Steuerer von chemischen Verfahrensanlagen",
    "Steurer von Erdöl- und Erdgasraffinationsanlagen",
    "Steuerer von Verfahren in der Metallerzeugung",
    "Techniker in der Prozesssteuerung, anderweitig nicht genannt",
    "Biotechniker (ohne medizinische Fachberufe)",
    "Agrartechniker",
    "Forsttechniker",
    "Technische Schiffsoffiziere",
    "Flugverkehrslotsen",
    "Flugsicherungstechniker",
    "Medizintechniker im Bereich bildgebende Verfahren und Therapiegeräte",
    "Medizintechniker im Bereich Labor und Pathologie",
    "Pharmazeutisch-technische Assistenten",
    "Medizinische und zahnmedizinische Prothetiktechniker",
    "Nicht akademische Krankenpflegefachkräfte",
    "Nicht akademische Geburtshilfefachkräfte",
    "Nicht akademische Fachkräfte in traditioneller und komplementärer Medizin",
    "Veterinärmedizinische Fachkräfte und Assistenten",
    "Zahnmedizinische Assistenten und Dentalhygieniker",
    "Fachkräfte im Bereich medizinische Dokumentation und Information",
    "Fachkräfte in der öffentlichen Gesundheitsfürsorge",
    "Augenoptiker",
    "Physiotherapeutische Techniker und Assistenten",
    "Medizinische Assistenten",
    "Nicht akademische Kontrolleure und Beauftragte in den Bereichen Umwelt- und Arbeitsmedizin sowie verwandte Berufe",
    "Rettungsdienstpersonal",
    "Assistenzberufe im Gesundheitswesen, anderweitig nicht genannt",
    "Wertpapierhändler, -makler und Finanzmakler",
    "Kreditsachbearbeiter",
    "Nicht akademische Fachkräfte im Rechnungswesen",
    "Nicht akademische statistische, mathematische und verwandte Fachkräfte",
    "Schätzer und Schadensgutachter",
    "Versicherungsvertreter",
    "Vertriebsagenten",
    "Einkäufer",
    "Handelsmakler",
    "Fachkräfte für Abrechnungs- und Speditionsdienstleistungen",
    "Konferenz- und Veranstaltungsplaner",
    "Arbeits- und Personalvermittler",
    "Immobilienmakler und -verwalter",
    "Fachkräfte für unternehmensbezogene Dienstleistungen, anderweitig nicht genannt",
    "Sekretariatsfachkräfte im juristischen Bereich",
    "Sekretariatsfachkräfte in Verwaltung und Geschäftsleitung",
    "Sekretariatsfachkräfte im Gesundheitswesen",
    "Nicht akademische Fachkräfte für Rechts- und verwandte Angelegenheiten",
    "Nicht akademische sozialpflegerische Fachkräfte",
    "Ordensbrüder/-schwestern und Seelsorgehelfer",
    "Athleten und Berufssportler",
    "Sportlehrer, Sporttrainer und Sportfunktionäre",
    "Trainer und Betreuer im Bereich Fitness und Erholung",
    "Raumgestalter und Dekorateure",
    "Fachkräfte in Kunstgalerien, Museen und Bibliotheken",
    "Küchenchefs",
    "Sonstige Fachkräfte in Gestaltung und Kultur",
    "Techniker für den Betrieb von Informations- und Kommunikationstechnologie",
    "Techniker für die Anwenderbetreuung in der Informations- und Kommunikationstechnologie",
    "Techniker für Computernetzwerke und -systeme",
    "Webmaster",
    "Techniker für Rundfunk und audiovisuelle Medien",
    "Telekommunikationstechniker"
    
}
# Convert to dictionary with the same value for all keys
hochspezialisiertebeschäftigte = {key: "Hochspezialisierte Beschäftigte" for key in Hochspezialisierte_Beschäftigte}

# Display the resulting dictionary
print(hochspezialisiertebeschäftigte)
# Out:
# {'Anwendungsprogrammierer': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Fachkräfte für Datenbanken und Netzwerke, anderweitig nicht genannt': 'Hochspezialisierte Beschäftigte', 'Ausbilder im Bereich Informationstechnologie': 'Hochspezialisierte Beschäftigte', 'Raum-, Stadt- und Verkehrsplaner': 'Hochspezialisierte Beschäftigte', 'Wertpapierhändler, -makler und Finanzmakler': 'Hochspezialisierte Beschäftigte', 'Softwareentwickler': 'Hochspezialisierte Beschäftigte', 'Handelsmakler': 'Hochspezialisierte Beschäftigte', 'Assistenzberufe im Gesundheitswesen, anderweitig nicht genannt': 'Hochspezialisierte Beschäftigte', 'Umweltwissenschaftler': 'Hochspezialisierte Beschäftigte', 'Flugverkehrslotsen': 'Hochspezialisierte Beschäftigte', 'Sekretariatsfachkräfte in Verwaltung und Geschäftsleitung': 'Hochspezialisierte Beschäftigte', 'Architekten': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Fachkräfte im Bereich Vertrieb (Technik und Medizin, ohne Informations- und Kommunikationstechnologie)': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Fachkräfte in der strategischen Planung in Politik und Wirtschaft': 'Hochspezialisierte Beschäftigte', 'Bautechniker': 'Hochspezialisierte Beschäftigte', 'Sprecher im Rundfunk, Fernsehen und sonstigen Medien': 'Hochspezialisierte Beschäftigte', 'Webmaster': 'Hochspezialisierte Beschäftigte', 'Grafik- und Multimediadesigner': 'Hochspezialisierte Beschäftigte', 'Wirtschafts- und Produktionsingenieure': 'Hochspezialisierte Beschäftigte', 'Umweltschutzingenieure': 'Hochspezialisierte Beschäftigte', 'Nicht akademische Krankenpflegefachkräfte': 'Hochspezialisierte Beschäftigte', 'Techniker im Bereich Elektronik': 'Hochspezialisierte Beschäftigte', 'Techniker in der Prozesssteuerung, anderweitig nicht genannt': 'Hochspezialisierte Beschäftigte', 'Meteorologen': 'Hochspezialisierte Beschäftigte', 'Sekretariatsfachkräfte im Gesundheitswesen': 'Hochspezialisierte Beschäftigte', 'Nicht akademische statistische, mathematische und verwandte Fachkräfte': 'Hochspezialisierte Beschäftigte', 'Finanzanalysten': 'Hochspezialisierte Beschäftigte', 'Sozialarbeiter': 'Hochspezialisierte Beschäftigte', 'Pharmazeutisch-technische Assistenten': 'Hochspezialisierte Beschäftigte', 'Steurer von Erdöl- und Erdgasraffinationsanlagen': 'Hochspezialisierte Beschäftigte', 'Bergbauingenieure, Metallurgen und verwandte Berufe': 'Hochspezialisierte Beschäftigte', 'Schauspieler': 'Hochspezialisierte Beschäftigte', 'Apotheker': 'Hochspezialisierte Beschäftigte', 'Ordensbrüder/-schwestern und Seelsorgehelfer': 'Hochspezialisierte Beschäftigte', 'Forsttechniker': 'Hochspezialisierte Beschäftigte', 'Material- und ingenieurtechnische Fachkräfte, anderweitig nicht genannt': 'Hochspezialisierte Beschäftigte', 'Chemieingenieure': 'Hochspezialisierte Beschäftigte', 'Fachkräfte in Personalschulung und -entwicklung': 'Hochspezialisierte Beschäftigte', 'Rettungsdienstpersonal': 'Hochspezialisierte Beschäftigte', 'Volkswirtschaftler': 'Hochspezialisierte Beschäftigte', 'Medizinische und zahnmedizinische Prothetiktechniker': 'Hochspezialisierte Beschäftigte', 'Physiotherapeuten': 'Hochspezialisierte Beschäftigte', 'Maschinenbautechniker': 'Hochspezialisierte Beschäftigte', 'Versicherungsvertreter': 'Hochspezialisierte Beschäftigte', 'Produkt- und Textildesigner': 'Hochspezialisierte Beschäftigte', 'Medizintechniker im Bereich bildgebende Verfahren und Therapiegeräte': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Fachkräfte in den Bereichen Umwelt- und Arbeitsmedizin sowie Hygiene': 'Hochspezialisierte Beschäftigte', 'Küchenchefs': 'Hochspezialisierte Beschäftigte', 'Kartografen und Vermessungsingenieure': 'Hochspezialisierte Beschäftigte', 'Ingenieure, anderweitig nicht genannt': 'Hochspezialisierte Beschäftigte', 'Ingenieure im Bereich Elektronik': 'Hochspezialisierte Beschäftigte', 'Maschinenbauingenieure': 'Hochspezialisierte Beschäftigte', 'Fachkräfte in Kunstgale ...

# %%
selbständig= {
    'Architekten',
    'Allgemeinärzte',
    'Fachärzte',
    'Tierärzte',
    'Zahnärzte',
    'Apotheker',
    'Audiologen und Sprachthearpeuten',
    'Optometristen und Orthoptisten',
    'Anwälte',
    "Fotografen",
    "Psychologen",
    "Bildende Künstler",
    "Musiker, Sänger und Komponisten",
    "Tänzer und Choreografen",
    "Autoren und verwandte schriftstellerische Berufe",
}
# Convert to dictionary with the same value for all keys
selbständig = {key: "Selbständig" for key in selbständig}

 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen der Altenbetreuung': 'Mittleres Management', 'Führungskräfte in Werbung und Öffentlichkeitsarbeit': 'Mittleres Management', 'Führungskräfte in der Erbringung von speziellen Dienstleistungen, anderweitig nicht genannt': 'Mittleres Management', 'Führungskräfte in Groß- und Einzelhandel': 'Mittleres Management'}

# %%
top_management = {
'Angehörige gesetzgebender Körperschaften',
'Leitende Verwaltungsbedienstete',
'Leitende Bedienstete von Interessenorganisationen',
'Geschäftsführer und Vorstände',
"Führungskräfte in Forschung und Entwicklung",
"Führungskräfte im Bereich Finanzen",
"Führungskräfte im Personalwesen",
"Führungskräfte in Unternehmenspolitik und -planung",

}
# Convert to dictionary with the same value for all keys
top_management = {key: "Top Managment" for key in top_management}

# Display the resulting dictionary
print(selbständig)
# Out:
# {'Musiker, Sänger und Komponisten': 'Selbständig', 'Allgemeinärzte': 'Selbständig', 'Architekten': 'Selbständig', 'Apotheker': 'Selbständig', 'Audiologen und Sprachthearpeuten': 'Selbständig', 'Autoren und verwandte schriftstellerische Berufe': 'Selbständig', 'Zahnärzte': 'Selbständig', 'Tierärzte': 'Selbständig', 'Fachärzte': 'Selbständig', 'Optometristen und Orthoptisten': 'Selbständig', 'Psychologen': 'Selbständig', 'Bildende Künstler': 'Selbständig', 'Fotografen': 'Selbständig', 'Tänzer und Choreografen': 'Selbständig', 'Anwälte': 'Selbständig'}

# %%
import pandas as pd
from openpyxl import load_workbook
# Load the workbook
workbook = load_workbook('/Users/leonardhaas/code/streamlit/data/Zensus22_Sonderauswertung_Haas.xlsx', read_only=True)

# Get all sheet names
sheet_names = workbook.sheetnames

# %%
berufs_gattungen_4 = pd.read_excel('/Users/leonardhaas/code/streamlit/data/Zensus22_Sonderauswertung_Haas.xlsx', sheet_name=sheet_names[6], header=3)  # Row 2 as header (index 1)

# %%
# List of dictionaries to map
dict_list = [dienstleistungsarbeiter, industriearbeiter, beamte, hochspezialisiertebeschäftigte, 
             selbständig, middle_management, top_management]

berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[0])
berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[1])
berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[2])
berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[3])
berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[4])
berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[5])
#berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[6])

# %%
# List of dictionaries to map
dict_list = [dienstleistungsarbeiter, industriearbeiter, beamte, hochspezialisiertebeschäftigte, 
             selbständig, middle_management, top_management]

# Initialize 'fraktion' column with the first mapping
berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[0])

# Sequentially map using the next dictionaries, filling missing values
for i in range(1, len(dict_list)):
    berufs_gattungen_4['fraktion'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[i]).fillna(berufs_gattungen_4['fraktion'])

# Optional: You can print the resulting DataFrame to verify the final result
print(berufs_gattungen_4)
# Out:
#      ISCO-Code                                        Bezeichnung Insgesamt  \
# 0    Insgesamt                                          Insgesamt  41043450
# 1         0110               Offiziere in regulären Streitkräften     22030
# 2         0210         Unteroffiziere in regulären Streitkräften      22020
# 3         0310  Angehörige der regulären Streitkräfte in sonst...    107160
# 4         1111           Angehörige gesetzgebender Körperschaften      9740
# ..         ...                                                ...       ...
# 416       9613                 Straßenkehrer und verwandte Berufe      6760
# 417       9621           Boten, Paketauslieferer und Gepäckträger    157600
# 418       9622                               Gelegenheitsarbeiter       690
# 419       9623    Zählerableser, Automatenbefüller und -kassierer      9010
# 420       9629      Hilfsarbeitskräfte, anderweitig nicht genannt     74020
#
#     Baden-Württemberg   Bayern   Berlin Brandenburg  Bremen Hamburg   Hessen  \
# 0             5667810  7024330  1772180     1208030  321090  948980  3048160
# 1                1200     2180      750         960       /     430      790
# 2                1690     2220      400         680     300     390      880
# 3                7690    17460     2470        4320     800    1340     5640
# 4                1680     2250      290           /       /       /      700
# ..                ...      ...      ...         ...     ...     ...      ...
# 416               520      990      750         250       /       /      550
# 417             27650    27140     4030        3900    1370    1520    12650
# 418                 /        /        /           /       /       /        /
# 419              1200     1730      370         220       /       /      740
# 420              8430     8730     7290        2830    1180    1910     7050
#
#     Mecklenburg-Vorpommern Niedersachsen Nordrhein-Westfalen Rheinland-Pfalz  \
# 0                   723350       3935110             8621290         2025940
# 1                      810          4690                4560            1740
# 2                     1470          4960                3620            1340
# 3                     4940         12340               20010            8300
# 4                      240           830                1500             500
# ..                     ...           ...                 ...             ...
# 416                      /           700                1590             460
# 417                   2160         17170               31990            7860
# 418                      /             /                 270               /
# 419                      /           890                1890             500
# 420                   1190          6520               16960            3180
#
#     Saarland  Sachsen Sachsen-Anhalt Schleswig-Holstein Thüringen  \
# 0     470130  1837640         971950            1479240    988230
# 1        380     1130            560               1100       620
# 2        330      830            880               1340       700
# 3       1140     3710           4070               9510      3440
# 4          /      480            250                290       280
# ..       ...      ...            ...                ...       ...
# 416        /        /              /                220         /
# 417     1640     6750           3230               5580      2950
# 418        /        /              /                  /         /
# 419        /      260              /                370       230
# 420      720     2500           2030               2220      1270
#
#                     fraktion
# 0                        NaN
# 1               Staatsdiener
# 2                        NaN
# 3               Staatsdiener
# 4              Top Managment
# ..                       ...
# 416  Dienstleistungsarbeiter
# 417  Dienstleistungsarbeiter
# 418  Dienstleistungsarbeiter
# 419  Dienstleistungsarbeiter
# 420  Dienstleistungsarbeiter
#
# [421 rows x 20 columns]

# %%
berufs_gattungen_4=berufs_gattungen_4.replace('/','0')
berufs_gattungen_4['Insgesamt'] = berufs_gattungen_4['Insgesamt'].astype(int)

# %%
total =berufs_gattungen_4['Insgesamt'][0]

# %%
(berufs_gattungen_4.groupby(['fraktion'])['Insgesamt'].sum()/ total) * 100
# Out:
# fraktion
# Dienstleistungsarbeiter            16.460361
# Hochspezialisierte Beschäftigte    30.561563
# Industriearbeiter                  21.125831
# Mittleres Management                2.631431
# Selbständig                         2.925948
# Staatsdiener                        7.936467
# Top Managment                       1.626423
# Name: Insgesamt, dtype: float64

# %%
berufs_gattungen_4.drop(0,inplace=True)
berufs_gattungen_4['ISCO-Code'] = berufs_gattungen_4['ISCO-Code'].astype(int)

# %%
berufs_gattungen_4.query("fraktion=='Industriearbeiter'").sort_values(by="Insgesamt",ascending=False).head(20)
# Out:
#      ISCO-Code                                        Bezeichnung  Insgesamt  \
# 227       4321                  Fachkräfte in der Lagerwirtschaft     652740
# 312       7233  Landmaschinen- und Industriemaschinenmechanike...     618310
# 308       7223          Werkzeugmaschineneinrichter und -bediener     412030
# 409       9333                Frachtarbeiter und verwandte Berufe     360140
# 310       7231             Kraftfahrzeugmechaniker und -schlosser     353740
# 239     2480   14580           6970              11280      6810
# 275     3110   10740           6070              13840      5110
# 412     2900    8440           5560               9650      5230
# 326     3270   11950           6850               9150      7560
# 296     2600   11710           8000               8610      7230
# 280      860    7400           5250              12920      4100
# 338     1850    9390           4780               7190      5660
# 327     2770    9100           5980               7800      5360
# 307     2530    8560           4990               2950      6380
# 376     1300    9060           6870               3990      5050
# 330     1620    7730           3940               6230      4260
# 286     1240    8940           5530               6680      5020
# 298     1620    7080           4010               6520      3780
# 329     1190    5530           3150               3010      2970
#
#               fraktion
# 227  Industriearbeiter
# 312  Industriearbeiter
# 308  Industriearbeiter
# 409  Industriearbeiter
# 310  Industriearbeiter
# 406  Industriearbeiter
# 239  Industriearbeiter
# 275  Industriearbeiter
# 412  Industriearbeiter
# 326  Industriearbeiter
# 296  Industriearbeiter
# 280  Industriearbeiter
# 338  Industriearbeiter
# 327  Industriearbeiter
# 307  Industriearbeiter
# 376  Industriearbeiter
# 330  Industriearbeiter
# 286  Industriearbeiter
# 298  Industriearbeiter
# 329  Industriearbeiter

# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import plotly.io as pio

def generate_bubble_swarm_chart(df):
    # Validate input DataFrame
    required_columns = ['category', 'size_markers', 'value_y_axis']
    if not all(col in df.columns for col in required_columns):
        raise ValueError(f"DataFrame must contain columns: {required_columns}")
    
    # Ensure categories are strings
    df['category'] = df['category'].astype(str)
    
    # Get unique categories and assign colors
    categories = df['category'].unique()
    
    # Prepare color palette with fallback
    colors = [
        'rgba(31, 119, 180, 0.7)',   # Blue
        'rgba(255, 127, 14, 0.7)',   # Orange
        'rgba(44, 160, 44, 0.7)',    # Green
        'rgba(214, 39, 40, 0.7)',    # Red
        'rgba(148, 103, 189, 0.7)'   # Purple
    ]
    
    # Extend colors if more categories than predefined colors
    if len(categories) > len(colors):
        # Generate additional colors if needed
        additional_colors = [f'rgba({np.random.randint(0,256)}, {np.random.randint(0,256)}, {np.random.randint(0,256)}, 0.7)' 
                              for _ in range(len(categories) - len(colors))]
        colors.extend(additional_colors)
    
    # Create traces
    traces = []
    for i, category in enumerate(categories):
        # Filter data for each category
        category_df = df[df['category'] == category]
        
        # Create randomized x-coordinates to spread out categories on the x-axis
        x = np.random.normal(loc=i*4, scale=0.3, size=len(category_df))

        y_jittered = category_df['value_y_axis'] + np.random.normal(loc=0, scale=0.1, size=len(category_df))
        
        # Create trace
        trace = go.Scatter(
            x=x,
            y=y_jittered,
            mode='markers',
            name=f'{category} (n={len(category_df)})',
            marker=dict(
                size=category_df['scale_markers'],
                color=colors[i],
                line=dict(width=1, color='rgba(0,0,0,0.5)'),
                opacity=0.7
            ),
            text=[f'<br>Subcategory: {subcategory}<br>ISCO-Code: {y:.2f}<br>Anzahl: {size:.2f}'
                  for y, size, subcategory in zip(category_df['value_y_axis'], 
                                                  category_df['size_markers'], 
                                                  category_df['subcategory'])],
            hoverinfo='text'
        )
        traces.append(trace)
    
    # Create layout
    layout = go.Layout(
        title='Klassenanalyse mit ISCO-Berufsgattung auf Basis von Zensusdaten',
        height=800,
        width=1500,
        xaxis=dict(
            title='Category Grouping',
            tickmode='array',
            tickvals=list(range(0, len(categories)*4, 4)),
            ticktext=categories
        ),
        yaxis=dict(
            title='Y-Axis Value',
                    range=[df['value_y_axis'].max()+1, df['value_y_axis'].min()-1],  # Swap min and max
                    autorange=False,  # Disable auto-ranging
                    rangemode='tozero'  # Ensure 0 is always visible
        ),
        hovermode='closest'
    )
    
    # Create and show figure
    fig = go.Figure(data=traces, layout=layout)
    pio.show(fig)
    
    # Optional: Save as HTML
    #pio.write_html(fig, file='bubble_swarm_chart.html')

# Debugging helper function
def print_dataframe_info(df):
    print("DataFrame Information:")
    print(f"Columns: {df.columns.tolist()}")
    print(f"Number of rows: {len(df)}")
    print("\nCategory counts:")
    print(df['category'].value_counts())
    print("\nFirst few rows:")
    print(df.head())
    print("\nColumn dtypes:")
    print(df.dtypes)

# %%
#plot_data = berufs_gattungen_4.copy().query('fraktion in ["Dienstleistungsarbeiter", "Industriearbeiter", "Hochspezialisierte Beschäftigte"]')[['fraktion','Insgesamt','ISCO-Code','Bezeichnung']]
plot_data = berufs_gattungen_4[['fraktion','Insgesamt','ISCO-Code','Bezeichnung']]

plot_data.columns =['category', 'size_markers', 'value_y_axis','subcategory']
plot_data.dropna(inplace=True)
plot_data.dtypes
# Out:
# /var/folders/05/nng50wx91lbfkkf4rcjhd68h0000gn/T/ipykernel_19027/1508060269.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# category        object
# size_markers     int64
# value_y_axis     int64
# subcategory     object
# dtype: object

# %%
plot_data['scale_markers'] = plot_data['size_markers'] /15000
# Out:
# /var/folders/05/nng50wx91lbfkkf4rcjhd68h0000gn/T/ipykernel_19027/1027194907.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
generate_bubble_swarm_chart(plot_data)
# Out:
# /var/folders/05/nng50wx91lbfkkf4rcjhd68h0000gn/T/ipykernel_19027/1878991448.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plot_data.head(20)
# Out:
#                            category  size_markers  value_y_axis
# 34  Hochspezialisierte Beschäftigte         23.15          2111
# 35  Hochspezialisierte Beschäftigte          1.54          2112
# 36  Hochspezialisierte Beschäftigte         29.40          2113
# 37  Hochspezialisierte Beschäftigte         11.06          2114
# 38  Hochspezialisierte Beschäftigte         27.28          2120
# 39  Hochspezialisierte Beschäftigte         41.73          2131
# 40  Hochspezialisierte Beschäftigte         55.41          2132
# 41  Hochspezialisierte Beschäftigte         22.06          2133
# 42  Hochspezialisierte Beschäftigte        147.96          2141
# 43  Hochspezialisierte Beschäftigte        104.85          2142
# 44  Hochspezialisierte Beschäftigte         16.75          2143
# 45  Hochspezialisierte Beschäftigte        293.49          2144
# 46  Hochspezialisierte Beschäftigte         43.95          2145
# 47  Hochspezialisierte Beschäftigte         19.66          2146
# 48  Hochspezialisierte Beschäftigte        165.58          2149
# 49  Hochspezialisierte Beschäftigte         73.57          2151
# 50  Hochspezialisierte Beschäftigte         68.68          2152
# 51  Hochspezialisierte Beschäftigte          9.00          2153
# 53  Hochspezialisierte Beschäftigte         17.57          2162
# 54  Hochspezialisierte Beschäftigte         53.81          2163
