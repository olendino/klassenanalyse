# %%
import pandas as pd
from openpyxl import load_workbook

# %%
# Load the workbook
workbook = load_workbook('../data/Zensus22_Sonderauswertung_Haas.xlsx', read_only=True)

# Get all sheet names
sheet_names = workbook.sheetnames

# %%
sheet_names
# Out:
# ['Titel',
#  'Impressum',
#  'Erläuterungen zur Methodik',
#  'ISCO Hauptgruppen (1-St.)',
#  'ISCO Berufsgruppen (2-St.)',
#  'ISCO Berufsuntergruppen (3-St.)',
#  'ISCO Berufsgattungen (4-St.)']

# %%
haupt_gruppen_1 = pd.read_excel('../data/Zensus22_Sonderauswertung_Haas.xlsx', sheet_name=sheet_names[3], header=3)  # Row 2 as header (index 1)
berufs_gruppen_2 = pd.read_excel('../data/Zensus22_Sonderauswertung_Haas.xlsx', sheet_name=sheet_names[4], header=3)  # Row 2 as header (index 1)
berufs_unter_gruppen_3 = pd.read_excel('../data/Zensus22_Sonderauswertung_Haas.xlsx', sheet_name=sheet_names[5], header=3)  # Row 2 as header (index 1)
berufs_gattungen_4 = pd.read_excel('../data/Zensus22_Sonderauswertung_Haas.xlsx', sheet_name=sheet_names[6], header=3)  # Row 2 as header (index 1)

# %%
berufs_gattungen_4

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 help(pd.DataFrame.drop())
#
# TypeError: drop() missing 1 required positional argument: 'self'
