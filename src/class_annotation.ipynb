# %%
import pandas as pd
import numpy as np
from dataclasses import dataclass, field
from typing import List, Dict, Optional, Any
import utils

# %%
service_worker = {
    "Allgemeine Bürokräfte",
    "Sekretariatskräfte (allgemein)",
    "Schreibkräfte und Bediener von Textverarbeitungsanlagen",
    "Datenerfasser",
    "Bank- und andere Schalterbedienstete",
    "Buchmacher, Croupiers und verwandte Berufe im Bereich Glücks- und Wettspiele",
    "Pfandleiher und Geldverleiher",
    "Inkassobeauftragte und verwandte Berufe",
    "Reiseverkehrsfachkräfte",
    "Kundeninformationsfachkräfte in Call Centers",
    "Telefonisten",
    "Hotelrezeptionisten",
    "Auskunftspersonal",
    "Reiseleiter/Fremdenführer",
    "Interviewer im Bereich Umfragen und Marktforschung",
    "Bürokräfte im Rechnungswesen und in der Buchhaltung",
    "Bürokräfte in der Statistik, im Finanz- und Versicherungswesen",
    "Bürokräfte in der Lohnbuchhaltung",
    "Fachkräfte in der Lagerwirtschaft",
    "Bürokräfte in der Material- und Fertigungsplanung und verwandte Berufe",
    "Bürokräfte in der Transportwirtschaft und verwandte Berufe",
    "Bibliotheksassistenten",
    "Postverteiler und -sortierer",
    "Kodierer, Korrekturleser und verwandte Bürokräfte",
    "Bürokräfte für Registratur und Dokumentation",
    "Bürokräfte im Personalwesen",
    "Bürokräfte und verwandte Berufe, anderweitig nicht genannt",
    "Hilfsarbeitskräfte, anderweitig nicht genannt",
    "Zählerableser, Automatenbefüller und -kassierer",
    "Boten, Paketauslieferer und Gepäckträger",
    "Straßenkehrer und verwandte Berufe",
    "Auf der Straße arbeitende Dienstleistungskräfte und verwandte Berufe",
    "Regalbetreuer und -auffüller",
    "Sonstiges Reinigungspersonal",
    "Fensterputzer",
    "Reinigungspersonal und Hilfskräfte in Privathaushalten",
    "Reinigungspersonal und Hilfskräfte in Büros, Hotels und anderen Einrichtungen",
    "Handwäscher und Handbügler",
    "Fahrzeugreiniger",
    "Personenkraftwagen-, Taxi-, Kleintransporter- und Kleinbusfahrer",
    "Busfahrer und Straßenbahnführer",
    "Kammerjäger und andere Schädlingsbekämpfungsberufe",
    "Produkttester und -klassierer (ohne Nahrungsmittel und Getränke)",
    "Taucher",
    "Nahrungsmittel- und Getränkekoster und -klassierer",
    "Fassadenreiniger und Schornsteinfeger/Rauchfangkehrer",
    "Sicherheitswachpersonal",
    'Feuerwehrleute',
    'Polizisten (ohne Polizeikommissare)',
    'Gefängnisaufseher',
    "Schutzkräfte und Sicherheitsbedienstete, anderweitig nicht genannt",
    "Betreuungsberufe im Gesundheitswesen, anderweitig nicht genannt",
    "Kassierer und Kartenverkäufer",
    "Verkäufer und Verkaufshilfskräfte in Handelsgeschäften",
    "Mannequins/Dressmen und sonstige Modelle",
    "Produktvorführer",
    "Telefonverkäufer",
    "Tankwarte",
    "Imbissverkäufer",
    "Verkaufskräfte, anderweitig nicht genannt",
    "Kinderbetreuer",
    "Lernbetreuer",
    "Pflegehelfer",
    "Haus- und Familienpfleger",
    "Reisebegleiter und Stewards",
    "Schaffner",
    "Kellner",
    "Barkeeper",
    "Friseure",
    "Kosmetiker und verwandte Berufe",
    "Hauswirtschafter in Privathaushalten",
    "Hauswarte",
    "Astrologen, Wahrsager und verwandte Berufe",
    "Bestatter und Einbalsamierer",
    "Tierpfleger und -betreuer",
    "Fahrschullehrer",
    "Berufe im Bereich personenbezogener Dienstleistungen, anderweitig nicht genannt",
    "Verkaufsstand- und Marktverkäufer",
    "Gelegenheitsarbeiter"
}
# Convert to dictionary with the same value for all keys
dienstleistungsarbeiter = {key: "Dienstleistungsarbeiter*innen" for key in service_worker}

# Display the resulting dictionary
print(dienstleistungsarbeiter)
# Out:
# {'Tierpfleger und -betreuer': 'Dienstleistungsarbeiter*innen', 'Kundeninformationsfachkräfte in Call Centers': 'Dienstleistungsarbeiter*innen', 'Bürokräfte im Personalwesen': 'Dienstleistungsarbeiter*innen', 'Nahrungsmittel- und Getränkekoster und -klassierer': 'Dienstleistungsarbeiter*innen', 'Bürokräfte in der Statistik, im Finanz- und Versicherungswesen': 'Dienstleistungsarbeiter*innen', 'Bürokräfte in der Lohnbuchhaltung': 'Dienstleistungsarbeiter*innen', 'Reinigungspersonal und Hilfskräfte in Privathaushalten': 'Dienstleistungsarbeiter*innen', 'Fachkräfte in der Lagerwirtschaft': 'Dienstleistungsarbeiter*innen', 'Kellner': 'Dienstleistungsarbeiter*innen', 'Pfandleiher und Geldverleiher': 'Dienstleistungsarbeiter*innen', 'Bürokräfte und verwandte Berufe, anderweitig nicht genannt': 'Dienstleistungsarbeiter*innen', 'Schaffner': 'Dienstleistungsarbeiter*innen', 'Bürokräfte in der Material- und Fertigungsplanung und verwandte Berufe': 'Dienstleistungsarbeiter*innen', 'Auskunftspersonal': 'Dienstleistungsarbeiter*innen', 'Boten, Paketauslieferer und Gepäckträger': 'Dienstleistungsarbeiter*innen', 'Auf der Straße arbeitende Dienstleistungskräfte und verwandte Berufe': 'Dienstleistungsarbeiter*innen', 'Kosmetiker und verwandte Berufe': 'Dienstleistungsarbeiter*innen', 'Astrologen, Wahrsager und verwandte Berufe': 'Dienstleistungsarbeiter*innen', 'Reisebegleiter und Stewards': 'Dienstleistungsarbeiter*innen', 'Polizisten (ohne Polizeikommissare)': 'Dienstleistungsarbeiter*innen', 'Postverteiler und -sortierer': 'Dienstleistungsarbeiter*innen', 'Inkassobeauftragte und verwandte Berufe': 'Dienstleistungsarbeiter*innen', 'Verkäufer und Verkaufshilfskräfte in Handelsgeschäften': 'Dienstleistungsarbeiter*innen', 'Zählerableser, Automatenbefüller und -kassierer': 'Dienstleistungsarbeiter*innen', 'Reiseverkehrsfachkräfte': 'Dienstleistungsarbeiter*innen', 'Haus- und Familienpfleger': 'Dienstleistungsarbeiter*innen', 'Berufe im Bereich personenbezogener Dienstleistungen, anderweitig nicht genannt': 'Dienstleistungsarbeiter*innen', 'Datenerfasser': 'Dienstleistungsarbeiter*innen', 'Bank- und andere Schalterbedienstete': 'Dienstleistungsarbeiter*innen', 'Fahrschullehrer': 'Dienstleistungsarbeiter*innen', 'Hotelrezeptionisten': 'Dienstleistungsarbeiter*innen', 'Fassadenreiniger und Schornsteinfeger/Rauchfangkehrer': 'Dienstleistungsarbeiter*innen', 'Reiseleiter/Fremdenführer': 'Dienstleistungsarbeiter*innen', 'Busfahrer und Straßenbahnführer': 'Dienstleistungsarbeiter*innen', 'Barkeeper': 'Dienstleistungsarbeiter*innen', 'Mannequins/Dressmen und sonstige Modelle': 'Dienstleistungsarbeiter*innen', 'Fahrzeugreiniger': 'Dienstleistungsarbeiter*innen', 'Bürokräfte für Registratur und Dokumentation': 'Dienstleistungsarbeiter*innen', 'Fensterputzer': 'Dienstleistungsarbeiter*innen', 'Verkaufskräfte, anderweitig nicht genannt': 'Dienstleistungsarbeiter*innen', 'Verkaufsstand- und Marktverkäufer': 'Dienstleistungsarbeiter*innen', 'Lernbetreuer': 'Dienstleistungsarbeiter*innen', 'Interviewer im Bereich Umfragen und Marktforschung': 'Dienstleistungsarbeiter*innen', 'Allgemeine Bürokräfte': 'Dienstleistungsarbeiter*innen', 'Pflegehelfer': 'Dienstleistungsarbeiter*innen', 'Kassierer und Kartenverkäufer': 'Dienstleistungsarbeiter*innen', 'Handwäscher und Handbügler': 'Dienstleistungsarbeiter*innen', 'Straßenkehrer und verwandte Berufe': 'Dienstleistungsarbeiter*innen', 'Tankwarte': 'Dienstleistungsarbeiter*innen', 'Bürokräfte in der Transportwirtschaft und verwandte Berufe': 'Dienstleistungsarbeiter*innen', 'Sonstiges Reinigungspersonal': 'Dienstleistungsarbeiter*innen', 'Buchmacher, Croupiers und verwandte Berufe im Bereich Glücks- und Wettspiele': 'Dienstleistungsarbeiter*innen', 'Hauswarte': 'Dienstleistungsarbeiter*innen', 'Personenkraftwagen-, Taxi-, Kleintransporter- und Kleinbusfahrer': 'Dienstleistungsarbeiter*innen', 'Friseure': 'Dienstleistungsarbeiter*innen', 'Bibliotheksassistenten': 'Dienstleistungsarbeiter*innen', 'Sekretariatskräfte (allg ...

# %%
""" beamte ={ 
    'Feuerwehrleute',
    'Polizisten (ohne Polizeikommissare)',
    'Gefängnisaufseher',
    'Polizeikommissare und Kriminalbeamte',
    'Fachkräfte im Zolldienst und Grenzschutz'
    'Fachkräfte in der Steuerverwaltung'
    'Fachkräfte in Sozialverwaltung und -versicherung'
    'Fachkräfte bei staatlichen Pass-, Lizenz- und Genehmigungsstellen',
    "Fachkräfte im Zolldienst und Grenzschutz",
    "Fachkräfte in der Steuerverwaltung",
    "Fachkräfte in Sozialverwaltung und -versicherung",
    "Fachkräfte bei staatlichen Pass-, Lizenz- und Genehmigungsstellen",
    "Polizeikommissare und Kriminalbeamte",
    "Fachkräfte in der öffentlichen Verwaltung, anderweitig nicht genannt",
    "Universitäts- und Hochschullehrer",
    "Lehrkräfte im Bereich Berufsbildung",
    "Lehrkräfte im Sekundarbereich",
    "Lehrkräfte im Primarbereich",
    "Lehrkräfte und Erzieher im Vorschulbereich",
    "Pädagogik- und Didaktikspezialisten",
    "Lehrkräfte im Bereich Sonderpädagogik",
    "Richter",
    "Juristen, anderweitig nicht genannt",
    'Offiziere in regulären Streitkräften',
    'Unteroffiziere in regulären Streitkräften',
    'Unteroffiziere in regulären Streitkräften',
    'Angehörige der regulären Streitkräfte in sonstigen Rängen'
}

# Convert to dictionary with the same value for all keys
beamte = {key: "Staatsangestellte" for key in beamte}

# Display the resulting dictionary
print(type(beamte)) """
# Out:
# ' beamte ={ \n    \'Feuerwehrleute\',\n    \'Polizisten (ohne Polizeikommissare)\',\n    \'Gefängnisaufseher\',\n    \'Polizeikommissare und Kriminalbeamte\',\n    \'Fachkräfte im Zolldienst und Grenzschutz\'\n    \'Fachkräfte in der Steuerverwaltung\'\n    \'Fachkräfte in Sozialverwaltung und -versicherung\'\n    \'Fachkräfte bei staatlichen Pass-, Lizenz- und Genehmigungsstellen\',\n    "Fachkräfte im Zolldienst und Grenzschutz",\n    "Fachkräfte in der Steuerverwaltung",\n    "Fachkräfte in Sozialverwaltung und -versicherung",\n    "Fachkräfte bei staatlichen Pass-, Lizenz- und Genehmigungsstellen",\n    "Polizeikommissare und Kriminalbeamte",\n    "Fachkräfte in der öffentlichen Verwaltung, anderweitig nicht genannt",\n    "Universitäts- und Hochschullehrer",\n    "Lehrkräfte im Bereich Berufsbildung",\n    "Lehrkräfte im Sekundarbereich",\n    "Lehrkräfte im Primarbereich",\n    "Lehrkräfte und Erzieher im Vorschulbereich",\n    "Pädagogik- und Didaktikspezialisten",\n    "Lehrkräfte im Bereich Sonderpädagogik",\n    "Richter",\n    "Juristen, anderweitig nicht genannt",\n    \'Offiziere in regulären Streitkräften\',\n    \'Unteroffiziere in regulären Streitkräften\',\n    \'Unteroffiziere in regulären Streitkräften\',\n    \'Angehörige der regulären Streitkräfte in sonstigen Rängen\'\n}\n\n# Convert to dictionary with the same value for all keys\nbeamte = {key: "Staatsangestellte" for key in beamte}\n\n# Display the resulting dictionary\nprint(type(beamte)) '

# %% [markdown]
# ## Managers and super visors:
#
# ISCO-08 P. 40:
# The critical difference is that supervisors are responsible only for supervision of the activities of other workers whereas those classified in Major Group 1: Managers have overall responsibility for the operations of a business or organizational unit.

# %%
anleitender_beschäftigter={
    'Leiter eines Einzelhandelsgeschäftes',
    'Reinigungs- und Hauswirtschaftsleiter in Büros, Hotels und anderen Einrichtungen',
    'Verkaufsaufsichtskräfte in Handelsgeschäften',
    'Sekretariatsleiter',
    'Berufsberater und -analytiker und akademische und vergleichbare Personalfachleute'
    'Fachkräfte in Personalschulung und -entwicklung',
    "Produktionsleiter im Bergbau",
    "Produktionsleiter bei der Herstellung von Waren",
    "Bauleiter",
    'Schiffsführer, nautische Schiffsoffiziere und Schiffslotsen',
    'Flugzeugführer und verwandte Berufe'
}
# Convert to dictionary with the same value for all keys
anleitender_beschäftigter = {key: "Anleitende Beschäftigte" for key in anleitender_beschäftigter}

# Display the resulting dictionary
print(anleitender_beschäftigter)
# Out:
# {'Verkaufsaufsichtskräfte in Handelsgeschäften': 'Anleitende Beschäftigte', 'Produktionsleiter im Bergbau': 'Anleitende Beschäftigte', 'Bauleiter': 'Anleitende Beschäftigte', 'Produktionsleiter bei der Herstellung von Waren': 'Anleitende Beschäftigte', 'Flugzeugführer und verwandte Berufe': 'Anleitende Beschäftigte', 'Schiffsführer, nautische Schiffsoffiziere und Schiffslotsen': 'Anleitende Beschäftigte', 'Leiter eines Einzelhandelsgeschäftes': 'Anleitende Beschäftigte', 'Sekretariatsleiter': 'Anleitende Beschäftigte', 'Berufsberater und -analytiker und akademische und vergleichbare PersonalfachleuteFachkräfte in Personalschulung und -entwicklung': 'Anleitende Beschäftigte', 'Reinigungs- und Hauswirtschaftsleiter in Büros, Hotels und anderen Einrichtungen': 'Anleitende Beschäftigte'}

# %%
'Sekretariatsfachkräfte in Verwaltung und Geschäftsleitung' #gericht aber auch persönlicher assitent
# Out:
# 'Sekretariatsfachkräfte in Verwaltung und Geschäftsleitung'

# %%
industrie_arbeiter={
    'Arbeiter in der Abfallsortierung',
    'Arbeiter in der Abfall- und Wertstoffsammlung',
    'Küchenhilfen',
    'Zubereiter von Fast Food und anderen Imbissen',
    'Frachtarbeiter und verwandte Berufe',
    'Hilfsarbeiter bei der Herstellung von Waren, anderweitig nicht genannt',
    'Verpacker',
    "Hilfsarbeiter im Ackerbau",
    "Hilfsarbeiter in der Tierhaltung",
    "Hilfsarbeiter in Ackerbau und Tierhaltung (ohne ausgeprägten Schwerpunkt)",
    "Hilfsarbeiter im Gartenbau",
    "Hilfsarbeiter in der Forstwirtschaft",
    "Hilfsarbeiter in der Fischerei und Aquakultur",
    "Hilfsarbeiter im Bergbau und in der Gewinnung von Steinen und Erden",
    "Hilfsarbeiter im Tiefbau",
    "Hilfsarbeiter im Hochbau",
    "Fahrer schwerer Lastkraftwagen",
    "Führer von mobilen land- und forstwirtschaftlichen Maschinen",
    "Führer von Erdbewegungs- und verwandten Maschinen",
    "Kranführer, Aufzugmaschinisten und Bediener verwandter Hebeeinrichtungen",
    "Gabelstaplerfahrer und verwandte Berufe",
    "Deckspersonal auf Schiffen und verwandte Berufe",
    "Lokomotivführer",
    'Bediener von Sicherungs-, Signal- und Leittechnik im Schienennetzbetrieb',
     "Handwerks- und verwandte Berufe, anderweitig nicht genannt",
    "Bergleute und Grubenarbeiter",
    "Bediener von Mineral- und Gesteinsaufbereitungsanlagen",
    "Tiefbohrer und verwandte Berufe",
    "Bediener von Maschinen zur Herstellung und Verarbeitung von Zement, Steinen und sonstigen Mineralien",
    "Bediener von Anlagen in der Metallerzeugung und -umformung",
    "Bediener von Anlagen zur Metallveredlung, Plattierung und Beschichtung von Metallen",
    "Bediener von Anlagen und Maschinen für chemische Erzeugnisse",
    "Bediener von Anlagen für fotografische Erzeugnisse",
    "Bediener von Maschinen zur Herstellung von Gummiwaren",
    "Bediener von Maschinen zur Herstellung von Kunststoffwaren",
    "Bediener von Maschinen zur Herstellung von Papierwaren",
    "Bediener von Spinnstoffaufbereitungs-, Spinn- und Spulmaschinen",
    "Bediener von Web-, Strick- und Wirkmaschinen",
    "Bediener von Nähmaschinen",
    "Bediener von Bleich- und Färbemaschinen",
    "Bediener von Pelz- und Lederzurichtungs- und -vorbereitungsmaschinen",
    "Bediener von Maschinen zur Schuhherstellung und verwandte Berufe",
    "Bediener von Wäschereimaschinen",
    "Bediener von Maschinen zur Herstellung von Textil-, Pelz- und Lederwaren, anderweitig nicht genannt",
    "Bediener von Maschinen zur Herstellung von Nahrungs- und Genussmitteln",
    "Bediener von Anlagen zur Zellstoff- und Papierherstellung",
    "Bediener von Anlagen zur Holzaufbereitung",
    "Bediener von Anlagen zur Glas- und Keramikherstellung",
    "Bediener von Dampfmaschinen und -kesseln",
    "Bediener von Verpackungs-, Abfüll- und Etikettiermaschinen",
    "Bediener stationärer Anlagen und Maschinen, anderweitig nicht genannt",
    "Berufe der Montage von mechanischen Bauteilen",
    "Berufe der Montage von elektrischen und elektronischen Geräten",
    "Montageberufe, anderweitig nicht genannt",
    "Holztrockner und -konservierer",
    "Möbeltischler und verwandte Berufe",
    "Einrichter und Bediener von Holzbearbeitungsmaschinen",
    "Herren- und Damenschneider, Kürschner und Hutmacher",
    "Schnittmustermacher und Zuschneider",
    "Näher, Sticker und verwandte Berufe",
    "Polsterer und verwandte Berufe",
    "Pelzveredler, Gerber und Fellzurichter",
    "Schuhmacher und verwandte Berufe",
    "Tabakaufbereiter und Tabakwarenmacher",
    'Obst- und Gemüsekonservierer und verwandte Berufe',
    'Molkerei- und Käsereifachkräfte',
    'Bäcker, Konditoren und Konfektmacher',
    'Fleischer, Fischhändler und -verarbeiter und verwandte Berufe',
    'Installateure und Servicetechniker im Bereich Informations- und Kommunikationstechnik',
    "Former und Kernmacher (für Metallguss)",
    "Schweißer und Brennschneider",
    "Blechkaltverformer",
    "Baumetallverformer und Metallbauer",
    "Verspannungsmonteure und Seilspleißer",
    "Grobschmiede, Hammerschmiede und Schmiedepresser",
    "Werkzeugmechaniker und verwandte Berufe",
    "Werkzeugmaschineneinrichter und -bediener",
    "Metallpolierer, Rundschleifer und Werkzeugschärfer",
    "Kraftfahrzeugmechaniker und -schlosser",
    "Flugmotorenmechaniker und -schlosser",
    "Landmaschinen- und Industriemaschinenmechaniker und -schlosser",
    "Fahrradmechaniker und verwandte Berufe",
    "Präzisionsinstrumentenmacher und -instandsetzer",
    "Musikinstrumentenbauer und -stimmer",
    "Schmuckwarenhersteller und Edelmetallbearbeiter",
    "Keramiker und verwandte Berufe",
    "Glasmacher, -schneider, -schleifer und -veredler",
    "Schildermaler, Dekormaler, Graveure und Ätzer",
    "Kunsthandwerkliche Berufe für Holz, Korbwaren und verwandte Materialien",
    "Kunsthandwerkliche Berufe für Textilien, Leder und verwandte Materialien",
    "Kunsthandwerkliche Berufe, anderweitig nicht genannt",
    "Techniker in der Druckvorstufe",
    "Drucker",
    "Berufe in der Druckweiterverarbeitung und Buchbinder",
    "Bauelektriker und verwandte Berufe",
    "Elektromechaniker und verwandte Berufe",
    "Elektroleitungsinstallateure und Wartungspersonal",
    "Elektroniker und Elektronik-Servicetechniker",
    "Ackerbauern und Gemüseanbauer",
    "Baum- und Strauchfrüchteanbauer",
    "Gärtner, Saat- und Pflanzenzüchter",
    "Nutztierhalter (ohne Geflügel) und Milchproduzenten",
    "Geflügelhalter",
    "Imker und Seidenraupenzüchter",
    "Tierhalter, anderweitig nicht genannt",
    "Landwirte mit Ackerbau und Tierhaltung (ohne ausgeprägten Schwerpunkt)",
    "Forstarbeitskräfte und verwandte Berufe",
    "Fachkräfte im Bereich Aquakultur",
    "Binnen- und Küstenfischer",
    "Hochseefischer",
    "Rohbaufacharbeiter im Hochbau",
    "Maurer und verwandte Berufe",
    "Steinmetze, Steinspalter, -bearbeiter und Steinbildhauer",
    "Betonierer, Betonoberflächenfertiger und verwandte Berufe",
    "Zimmerleute und Bautischler",
    "Baukonstruktions- und verwandte Berufe, anderweitig nicht genannt",
    "Dachdecker",
    "Boden- und Fliesenleger",
    "Stuckateure",
    "Isolierer",
    "Glaser",
    "Bauspengler und Sanitär- und Heizungsinstallateure",
    "Klima- und Kälteanlagenbauer",
    "Maler und verwandte Berufe",
    "Lackierer und verwandte Berufe",
    "Köche",
    "Fachkräfte in der Lagerwirtschaft",
    'Führer von Fahrzeugen und Maschinen mit Zugtierantrieb',
    'Führer von Handwagen und pedalbetriebenen Fahrzeugen',
    'Sprengmeister und Sprengbeauftragte'
    
}
# Convert to dictionary with the same value for all keys
industriearbeiter = {key: "Industriearbeiter*innen" for key in industrie_arbeiter}

# Display the resulting dictionary
print(industriearbeiter)
# Out:
# {'Hilfsarbeiter in der Forstwirtschaft': 'Industriearbeiter*innen', 'Deckspersonal auf Schiffen und verwandte Berufe': 'Industriearbeiter*innen', 'Pelzveredler, Gerber und Fellzurichter': 'Industriearbeiter*innen', 'Installateure und Servicetechniker im Bereich Informations- und Kommunikationstechnik': 'Industriearbeiter*innen', 'Maler und verwandte Berufe': 'Industriearbeiter*innen', 'Hilfsarbeiter im Ackerbau': 'Industriearbeiter*innen', 'Fachkräfte in der Lagerwirtschaft': 'Industriearbeiter*innen', 'Führer von Erdbewegungs- und verwandten Maschinen': 'Industriearbeiter*innen', 'Hilfsarbeiter im Hochbau': 'Industriearbeiter*innen', 'Grobschmiede, Hammerschmiede und Schmiedepresser': 'Industriearbeiter*innen', 'Stuckateure': 'Industriearbeiter*innen', 'Bediener von Maschinen zur Herstellung von Papierwaren': 'Industriearbeiter*innen', 'Präzisionsinstrumentenmacher und -instandsetzer': 'Industriearbeiter*innen', 'Nutztierhalter (ohne Geflügel) und Milchproduzenten': 'Industriearbeiter*innen', 'Hilfsarbeiter in Ackerbau und Tierhaltung (ohne ausgeprägten Schwerpunkt)': 'Industriearbeiter*innen', 'Kunsthandwerkliche Berufe für Textilien, Leder und verwandte Materialien': 'Industriearbeiter*innen', 'Musikinstrumentenbauer und -stimmer': 'Industriearbeiter*innen', 'Maurer und verwandte Berufe': 'Industriearbeiter*innen', 'Frachtarbeiter und verwandte Berufe': 'Industriearbeiter*innen', 'Näher, Sticker und verwandte Berufe': 'Industriearbeiter*innen', 'Gärtner, Saat- und Pflanzenzüchter': 'Industriearbeiter*innen', 'Bediener von Wäschereimaschinen': 'Industriearbeiter*innen', 'Berufe der Montage von elektrischen und elektronischen Geräten': 'Industriearbeiter*innen', 'Bediener von Web-, Strick- und Wirkmaschinen': 'Industriearbeiter*innen', 'Bauelektriker und verwandte Berufe': 'Industriearbeiter*innen', 'Bediener von Maschinen zur Herstellung und Verarbeitung von Zement, Steinen und sonstigen Mineralien': 'Industriearbeiter*innen', 'Herren- und Damenschneider, Kürschner und Hutmacher': 'Industriearbeiter*innen', 'Imker und Seidenraupenzüchter': 'Industriearbeiter*innen', 'Hilfsarbeiter in der Tierhaltung': 'Industriearbeiter*innen', 'Glaser': 'Industriearbeiter*innen', 'Polsterer und verwandte Berufe': 'Industriearbeiter*innen', 'Verpacker': 'Industriearbeiter*innen', 'Steinmetze, Steinspalter, -bearbeiter und Steinbildhauer': 'Industriearbeiter*innen', 'Elektroleitungsinstallateure und Wartungspersonal': 'Industriearbeiter*innen', 'Handwerks- und verwandte Berufe, anderweitig nicht genannt': 'Industriearbeiter*innen', 'Bediener von Bleich- und Färbemaschinen': 'Industriearbeiter*innen', 'Tabakaufbereiter und Tabakwarenmacher': 'Industriearbeiter*innen', 'Bediener von Anlagen für fotografische Erzeugnisse': 'Industriearbeiter*innen', 'Bediener von Sicherungs-, Signal- und Leittechnik im Schienennetzbetrieb': 'Industriearbeiter*innen', 'Landwirte mit Ackerbau und Tierhaltung (ohne ausgeprägten Schwerpunkt)': 'Industriearbeiter*innen', 'Bediener von Maschinen zur Schuhherstellung und verwandte Berufe': 'Industriearbeiter*innen', 'Schuhmacher und verwandte Berufe': 'Industriearbeiter*innen', 'Bediener von Anlagen zur Holzaufbereitung': 'Industriearbeiter*innen', 'Holztrockner und -konservierer': 'Industriearbeiter*innen', 'Klima- und Kälteanlagenbauer': 'Industriearbeiter*innen', 'Bediener von Maschinen zur Herstellung von Gummiwaren': 'Industriearbeiter*innen', 'Gabelstaplerfahrer und verwandte Berufe': 'Industriearbeiter*innen', 'Bediener von Maschinen zur Herstellung von Kunststoffwaren': 'Industriearbeiter*innen', 'Former und Kernmacher (für Metallguss)': 'Industriearbeiter*innen', 'Köche': 'Industriearbeiter*innen', 'Bediener von Nähmaschinen': 'Industriearbeiter*innen', 'Montageberufe, anderweitig nicht genannt': 'Industriearbeiter*innen', 'Werkzeugmaschineneinrichter und -bediener': 'Industriearbeiter*innen', 'Berufe in der Druckweiterverarbeitung und Buchbinder': 'Industriearbeiter*innen', 'Schmuckwarenhersteller und Edelmet ...

# %%
Hochspezialisierte_Beschäftigte = {
    "Physiker und Astronomen",
    "Meteorologen",
    "Chemiker",
    "Geologen und Geophysiker",
    "Mathematiker, Versicherungsmathematiker und Statistiker",
    "Biologen, Botaniker, Zoologen und verwandte Berufe",
    "Agrar-, Forst- und Fischereiwissenschaftler und -berater",
    "Umweltwissenschaftler",
    "Wirtschafts- und Produktionsingenieure",
    "Bauingenieure",
    "Umweltschutzingenieure",
    "Maschinenbauingenieure",
    "Chemieingenieure",
    "Bergbauingenieure, Metallurgen und verwandte Berufe",
    "Ingenieure, anderweitig nicht genannt",
    "Ingenieure im Bereich Elektrotechnik",
    "Ingenieure im Bereich Elektronik",
    "Ingenieure im Bereich Telekommunikationstechnik",
    "Kartografen und Vermessungsingenieure",
    "Akademische und vergleichbare Krankenpflegefachkräfte",
    "Akademische und vergleichbare Geburtshilfefachkräfte",
    "Akademische und vergleichbare Fachkräfte in der traditionellen und komplementären Medizin",
    "Feldscher und vergleichbare paramedizinische Praktiker",
    "Akademische und vergleichbare Fachkräfte in den Bereichen Umwelt- und Arbeitsmedizin sowie Hygiene",
    "Physiotherapeuten",
    "Diätologen und Ernährungsberater",
    "Audiologen und Sprachtherapeuten",
    "Optometristen und Orthoptisten",
    "Akademische und verwandte Gesundheitsberufe, anderweitig nicht genannt",
    "Ausbilder im Bereich Informationstechnologie",
    "Sonstige Sprachlehrer",
    "Sonstige Musiklehrer",
    "Sonstige Kunstlehrer",
    "Lehrkräfte, anderweitig nicht genannt",
    "Wirtschaftsprüfer, Steuerberater und verwandte Berufe",
    "Finanz- und Anlageberater",
    "Finanzanalysten",
    "Akademische und vergleichbare Fachkräfte im Bereich Management- und Organisationsanalyse",
    "Akademische und vergleichbare Fachkräfte in der strategischen Planung in Politik und Wirtschaft",
    "Berufsberater und -analytiker und akademische und vergleichbare Personalfachleute",
    "Fachkräfte in Personalschulung und -entwicklung",
    "Akademische und vergleichbare Fachkräfte in Werbung und Marketing",
    "Akademische und vergleichbare Fachkräfte in der Öffentlichkeitsarbeit",
    "Akademische und vergleichbare Fachkräfte im Bereich Vertrieb (Technik und Medizin, ohne Informations- und Kommunikationstechnologie)",
    "Akademische und vergleichbare Fachkräfte im Vertrieb von Informations- und Kommunikationstechnologie",
    "Systemanalytiker",
    "Softwareentwickler",
    "Web- und Multimediaentwickler",
    "Anwendungsprogrammierer",
    "Entwickler und Analytiker von Software und Anwendungen, anderweitig nicht genannt",
    "Datenbankentwickler und -administratoren",
    "Systemadministratoren",
    "Akademische und vergleichbare Fachkräfte für Computernetzwerke",
    "Akademische und vergleichbare Fachkräfte für Datenbanken und Netzwerke, anderweitig nicht genannt",
    "Archiv- und Museumswissenschaftler",
    "Bibliothekswissenschaftler und verwandte Informationswissenschaftler",
    "Volkswirtschaftler",
    "Soziologen, Anthropologen und verwandte Wissenschaftler",
    "Philosophen, Historiker und Politologen",
    "Sozialarbeiter",
    "Geistliche, Seelsorger",
    "Sprecher im Rundfunk, Fernsehen und sonstigen Medien",
    "Chemo- und Physikotechniker",
    "Bautechniker",
    "Elektrotechniker",
    "Techniker im Bereich Elektronik",
    "Maschinenbautechniker",
    "Chemiebetriebs- und Verfahrenstechniker",
    "Bergbau- und Hüttentechniker",
    "Technische Zeichner",
    "Material- und ingenieurtechnische Fachkräfte, anderweitig nicht genannt",
    "Steuerer von Energieerzeugungsanlagen",
    "Steuerer von Verbrennungs- und Wasserbehandlungsanlagen",
    "Steuerer von chemischen Verfahrensanlagen",
    "Steurer von Erdöl- und Erdgasraffinationsanlagen",
    "Steuerer von Verfahren in der Metallerzeugung",
    "Techniker in der Prozesssteuerung, anderweitig nicht genannt",
    "Biotechniker (ohne medizinische Fachberufe)",
    "Agrartechniker",
    "Forsttechniker",
    "Technische Schiffsoffiziere",
    "Flugverkehrslotsen",
    "Flugsicherungstechniker",
    "Medizintechniker im Bereich bildgebende Verfahren und Therapiegeräte",
    "Medizintechniker im Bereich Labor und Pathologie",
    "Pharmazeutisch-technische Assistenten",
    "Medizinische und zahnmedizinische Prothetiktechniker",
    "Nicht akademische Krankenpflegefachkräfte",
    "Nicht akademische Geburtshilfefachkräfte",
    "Nicht akademische Fachkräfte in traditioneller und komplementärer Medizin",
    "Veterinärmedizinische Fachkräfte und Assistenten",
    "Zahnmedizinische Assistenten und Dentalhygieniker",
    "Fachkräfte im Bereich medizinische Dokumentation und Information",
    "Fachkräfte in der öffentlichen Gesundheitsfürsorge",
    "Augenoptiker",
    "Physiotherapeutische Techniker und Assistenten",
    "Medizinische Assistenten",
    "Nicht akademische Kontrolleure und Beauftragte in den Bereichen Umwelt- und Arbeitsmedizin sowie verwandte Berufe",
    "Rettungsdienstpersonal",
    "Assistenzberufe im Gesundheitswesen, anderweitig nicht genannt",
    "Wertpapierhändler, -makler und Finanzmakler",
    "Kreditsachbearbeiter",
    "Nicht akademische Fachkräfte im Rechnungswesen",
    "Nicht akademische statistische, mathematische und verwandte Fachkräfte",
    "Schätzer und Schadensgutachter",
    "Versicherungsvertreter",
    "Vertriebsagenten",
    "Einkäufer",
    "Handelsmakler",
    "Fachkräfte für Abrechnungs- und Speditionsdienstleistungen",
    "Konferenz- und Veranstaltungsplaner",
    "Arbeits- und Personalvermittler",
    "Immobilienmakler und -verwalter",
    "Fachkräfte für unternehmensbezogene Dienstleistungen, anderweitig nicht genannt",
    "Sekretariatsfachkräfte im juristischen Bereich",
    "Sekretariatsfachkräfte in Verwaltung und Geschäftsleitung",
    "Sekretariatsfachkräfte im Gesundheitswesen",
    "Nicht akademische Fachkräfte für Rechts- und verwandte Angelegenheiten",
    "Nicht akademische sozialpflegerische Fachkräfte",
    "Ordensbrüder/-schwestern und Seelsorgehelfer",
    "Athleten und Berufssportler",
    "Sportlehrer, Sporttrainer und Sportfunktionäre",
    "Trainer und Betreuer im Bereich Fitness und Erholung",
    "Raumgestalter und Dekorateure",
    "Fachkräfte in Kunstgalerien, Museen und Bibliotheken",
    "Küchenchefs",
    "Sonstige Fachkräfte in Gestaltung und Kultur",
    "Techniker für den Betrieb von Informations- und Kommunikationstechnologie",
    "Techniker für die Anwenderbetreuung in der Informations- und Kommunikationstechnologie",
    "Techniker für Computernetzwerke und -systeme",
    "Webmaster",
    "Techniker für Rundfunk und audiovisuelle Medien",
    "Telekommunikationstechniker",
    'Polizeikommissare und Kriminalbeamte',
    'Fachkräfte im Zolldienst und Grenzschutz'
    'Fachkräfte in der Steuerverwaltung'
    'Fachkräfte in Sozialverwaltung und -versicherung'
    'Fachkräfte bei staatlichen Pass-, Lizenz- und Genehmigungsstellen',
    "Fachkräfte im Zolldienst und Grenzschutz",
    "Fachkräfte in der Steuerverwaltung",
    "Fachkräfte in Sozialverwaltung und -versicherung",
    "Fachkräfte bei staatlichen Pass-, Lizenz- und Genehmigungsstellen",
    "Polizeikommissare und Kriminalbeamte",
    "Fachkräfte in der öffentlichen Verwaltung, anderweitig nicht genannt",
    "Universitäts- und Hochschullehrer",
    "Lehrkräfte im Bereich Berufsbildung",
    "Lehrkräfte im Sekundarbereich",
    "Lehrkräfte im Primarbereich",
    "Lehrkräfte und Erzieher im Vorschulbereich",
    "Pädagogik- und Didaktikspezialisten",
    "Lehrkräfte im Bereich Sonderpädagogik",
    "Richter",
    "Juristen, anderweitig nicht genannt",
    'Architekten',
    'Allgemeinärzte',
    'Fachärzte',
    'Tierärzte',
    'Zahnärzte',
    'Apotheker',
    'Audiologen und Sprachthearpeuten',
    'Optometristen und Orthoptisten',
    'Anwälte',
    "Fotografen",
    "Psychologen",
    "Landschaftsarchitekten",
    "Produkt- und Textildesigner",
    "Raum-, Stadt- und Verkehrsplaner",
    "Grafik- und Multimediadesigner",
    "Wirtschaftsprüfer, Steuerberater und verwandte Berufe",
    "Finanz- und Anlageberater",
    "Übersetzer, Dolmetscher und andere Linguisten",
    "Journalisten",
    "Regisseure und Produzenten im Film- und Bühnenbereich sowie in verwandten Bereichen",
    "Schauspieler",
    "Bildende Künstler",
    "Bildende und darstellende Künstler, anderweitig nicht genannt",
    "Musiker, Sänger und Komponisten",
    "Tänzer und Choreografen",
    "Autoren und verwandte schriftstellerische Berufe"
    
}
# Convert to dictionary with the same value for all keys
hochspezialisiertebeschäftigte = {key: "Hochspezialisierte Beschäftigte" for key in Hochspezialisierte_Beschäftigte}

# Display the resulting dictionary
print(hochspezialisiertebeschäftigte)
# Out:
# {'Techniker für Computernetzwerke und -systeme': 'Hochspezialisierte Beschäftigte', 'Feldscher und vergleichbare paramedizinische Praktiker': 'Hochspezialisierte Beschäftigte', 'Anwendungsprogrammierer': 'Hochspezialisierte Beschäftigte', 'Maschinenbauingenieure': 'Hochspezialisierte Beschäftigte', 'Fachkräfte in Sozialverwaltung und -versicherung': 'Hochspezialisierte Beschäftigte', 'Sonstige Musiklehrer': 'Hochspezialisierte Beschäftigte', 'Nicht akademische Fachkräfte im Rechnungswesen': 'Hochspezialisierte Beschäftigte', 'Nicht akademische Krankenpflegefachkräfte': 'Hochspezialisierte Beschäftigte', 'Immobilienmakler und -verwalter': 'Hochspezialisierte Beschäftigte', 'Bauingenieure': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Fachkräfte im Bereich Management- und Organisationsanalyse': 'Hochspezialisierte Beschäftigte', 'Audiologen und Sprachtherapeuten': 'Hochspezialisierte Beschäftigte', 'Polizeikommissare und Kriminalbeamte': 'Hochspezialisierte Beschäftigte', 'Trainer und Betreuer im Bereich Fitness und Erholung': 'Hochspezialisierte Beschäftigte', 'Bergbauingenieure, Metallurgen und verwandte Berufe': 'Hochspezialisierte Beschäftigte', 'Journalisten': 'Hochspezialisierte Beschäftigte', 'Medizintechniker im Bereich bildgebende Verfahren und Therapiegeräte': 'Hochspezialisierte Beschäftigte', 'Konferenz- und Veranstaltungsplaner': 'Hochspezialisierte Beschäftigte', 'Übersetzer, Dolmetscher und andere Linguisten': 'Hochspezialisierte Beschäftigte', 'Grafik- und Multimediadesigner': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Fachkräfte für Computernetzwerke': 'Hochspezialisierte Beschäftigte', 'Web- und Multimediaentwickler': 'Hochspezialisierte Beschäftigte', 'Versicherungsvertreter': 'Hochspezialisierte Beschäftigte', 'Nicht akademische Fachkräfte in traditioneller und komplementärer Medizin': 'Hochspezialisierte Beschäftigte', 'Techniker für Rundfunk und audiovisuelle Medien': 'Hochspezialisierte Beschäftigte', 'Webmaster': 'Hochspezialisierte Beschäftigte', 'Fachkräfte für unternehmensbezogene Dienstleistungen, anderweitig nicht genannt': 'Hochspezialisierte Beschäftigte', 'Techniker für die Anwenderbetreuung in der Informations- und Kommunikationstechnologie': 'Hochspezialisierte Beschäftigte', 'Lehrkräfte, anderweitig nicht genannt': 'Hochspezialisierte Beschäftigte', 'Schauspieler': 'Hochspezialisierte Beschäftigte', 'Techniker in der Prozesssteuerung, anderweitig nicht genannt': 'Hochspezialisierte Beschäftigte', 'Chemieingenieure': 'Hochspezialisierte Beschäftigte', 'Finanzanalysten': 'Hochspezialisierte Beschäftigte', 'Systemanalytiker': 'Hochspezialisierte Beschäftigte', 'Fachkräfte in Kunstgalerien, Museen und Bibliotheken': 'Hochspezialisierte Beschäftigte', 'Bergbau- und Hüttentechniker': 'Hochspezialisierte Beschäftigte', 'Lehrkräfte im Primarbereich': 'Hochspezialisierte Beschäftigte', 'Mathematiker, Versicherungsmathematiker und Statistiker': 'Hochspezialisierte Beschäftigte', 'Medizinische Assistenten': 'Hochspezialisierte Beschäftigte', 'Lehrkräfte im Bereich Sonderpädagogik': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Geburtshilfefachkräfte': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Fachkräfte in der traditionellen und komplementären Medizin': 'Hochspezialisierte Beschäftigte', 'Umweltwissenschaftler': 'Hochspezialisierte Beschäftigte', 'Akademische und vergleichbare Fachkräfte im Bereich Vertrieb (Technik und Medizin, ohne Informations- und Kommunikationstechnologie)': 'Hochspezialisierte Beschäftigte', 'Steuerer von Verfahren in der Metallerzeugung': 'Hochspezialisierte Beschäftigte', 'Elektrotechniker': 'Hochspezialisierte Beschäftigte', 'Nicht akademische sozialpflegerische Fachkräfte': 'Hochspezialisierte Beschäftigte', 'Telekommunikationstechniker': 'Hochspezialisierte Beschäftigte', 'Ingenieure im Bereich Elektrotechnik': 'Hochspezialisierte Beschäftigte', 'Steurer von Erdöl- und Erdgasraffinationsanla ...

# %%
""" selbständig= {
    'Architekten',
    'Allgemeinärzte',
    'Fachärzte',
    'Tierärzte',
    'Zahnärzte',
    'Apotheker',
    'Audiologen und Sprachthearpeuten',
    'Optometristen und Orthoptisten',
    'Anwälte',
    "Fotografen",
    "Psychologen",
    "Landschaftsarchitekten",
    "Produkt- und Textildesigner",
    "Raum-, Stadt- und Verkehrsplaner",
    "Grafik- und Multimediadesigner",
    "Wirtschaftsprüfer, Steuerberater und verwandte Berufe",
    "Finanz- und Anlageberater",
    "Übersetzer, Dolmetscher und andere Linguisten",
    "Journalisten",
    "Regisseure und Produzenten im Film- und Bühnenbereich sowie in verwandten Bereichen",
    "Schauspieler",
    "Bildende Künstler",
    "Bildende und darstellende Künstler, anderweitig nicht genannt",
    "Musiker, Sänger und Komponisten",
    "Tänzer und Choreografen",
    "Autoren und verwandte schriftstellerische Berufe",
}
# Convert to dictionary with the same value for all keys
selbständig = {key: "Klassisch selbständige Tätigkeit" for key in selbständig}

# Display the resulting dictionary
print(type(selbständig)) """
# Out:
# ' selbständig= {\n    \'Architekten\',\n    \'Allgemeinärzte\',\n    \'Fachärzte\',\n    \'Tierärzte\',\n    \'Zahnärzte\',\n    \'Apotheker\',\n    \'Audiologen und Sprachthearpeuten\',\n    \'Optometristen und Orthoptisten\',\n    \'Anwälte\',\n    "Fotografen",\n    "Psychologen",\n    "Landschaftsarchitekten",\n    "Produkt- und Textildesigner",\n    "Raum-, Stadt- und Verkehrsplaner",\n    "Grafik- und Multimediadesigner",\n    "Wirtschaftsprüfer, Steuerberater und verwandte Berufe",\n    "Finanz- und Anlageberater",\n    "Übersetzer, Dolmetscher und andere Linguisten",\n    "Journalisten",\n    "Regisseure und Produzenten im Film- und Bühnenbereich sowie in verwandten Bereichen",\n    "Schauspieler",\n    "Bildende Künstler",\n    "Bildende und darstellende Künstler, anderweitig nicht genannt",\n    "Musiker, Sänger und Komponisten",\n    "Tänzer und Choreografen",\n    "Autoren und verwandte schriftstellerische Berufe",\n}\n# Convert to dictionary with the same value for all keys\nselbständig = {key: "Klassisch selbständige Tätigkeit" for key in selbständig}\n\n# Display the resulting dictionary\nprint(type(selbständig)) '

# %%
führungskraft_mittleres_management ={
    "Führungskräfte in Forschung und Entwicklung",
    "Führungskräfte im Bereich Finanzen",
    "Führungskräfte im Personalwesen",
    "Führungskräfte in Unternehmenspolitik und -planung",
    "Führungskräfte in der betrieblichen Verwaltung und in unternehmensbezogenen Dienstleistungen, anderweitig nicht genannt",
    "Führungskräfte in Vertrieb und Marketing",
    "Führungskräfte in Werbung und Öffentlichkeitsarbeit",
    "Führungskräfte in der Produktion in Land- und Forstwirtschaft",
    "Führungskräfte in der Produktion in Aquakultur und Fischerei",
    "Führungskräfte in der Produktion bei der Herstellung von Waren",
    "Führungskräfte in der Produktion im Bergbau",
    "Führungskräfte in der Produktion im Bau",
    "Führungskräfte in der Beschaffung, Logistik und in verwandten Bereichen",
    "Führungskräfte in der Erbringung von Dienstleistungen im Bereich Informations- und Kommunikationstechnologie",
    "Führungskräfte in der Erbringung von Dienstleistungen der Kinderbetreuung",
    "Führungskräfte in der Erbringung von Dienstleistungen im Gesundheitswesen",
    "Führungskräfte in der Erbringung von Dienstleistungen der Altenbetreuung",
    "Führungskräfte in der Erbringung von Dienstleistungen der Sozialfürsorge",
    "Führungskräfte in der Erbringung von Dienstleistungen des Bildungswesens",
    "Führungskräfte auf Filialebene in der Erbringung von Finanz- und Versicherungsdienstleistungen",
    "Führungskräfte in der Erbringung von speziellen Dienstleistungen, anderweitig nicht genannt",
    "Führungskräfte in Hotels",
    "Führungskräfte in Restaurants",
    "Führungskräfte in Groß- und Einzelhandel",
    "Führungskräfte in der Erbringung von Dienstleistungen im Bereich Sport, Erholung und Kultur",
    "Führungskräfte in der Erbringung von Dienstleistungen, anderweitig nicht genannt"


}
# Convert to dictionary with the same value for all keys
middle_management = {key: "Mittleres Management" for key in führungskraft_mittleres_management}

# Display the resulting dictionary
print(middle_management)
# Out:
# {'Führungskräfte in Groß- und Einzelhandel': 'Mittleres Management', 'Führungskräfte in Forschung und Entwicklung': 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen des Bildungswesens': 'Mittleres Management', 'Führungskräfte in der Erbringung von speziellen Dienstleistungen, anderweitig nicht genannt': 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen der Kinderbetreuung': 'Mittleres Management', 'Führungskräfte im Bereich Finanzen': 'Mittleres Management', 'Führungskräfte in Werbung und Öffentlichkeitsarbeit': 'Mittleres Management', 'Führungskräfte in der Produktion bei der Herstellung von Waren': 'Mittleres Management', 'Führungskräfte in der Produktion im Bergbau': 'Mittleres Management', 'Führungskräfte in der Produktion in Aquakultur und Fischerei': 'Mittleres Management', 'Führungskräfte in Hotels': 'Mittleres Management', 'Führungskräfte in der Produktion in Land- und Forstwirtschaft': 'Mittleres Management', 'Führungskräfte in der Produktion im Bau': 'Mittleres Management', 'Führungskräfte in Unternehmenspolitik und -planung': 'Mittleres Management', 'Führungskräfte auf Filialebene in der Erbringung von Finanz- und Versicherungsdienstleistungen': 'Mittleres Management', 'Führungskräfte in Restaurants': 'Mittleres Management', 'Führungskräfte im Personalwesen': 'Mittleres Management', 'Führungskräfte in der betrieblichen Verwaltung und in unternehmensbezogenen Dienstleistungen, anderweitig nicht genannt': 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen der Sozialfürsorge': 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen der Altenbetreuung': 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen im Bereich Informations- und Kommunikationstechnologie': 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen, anderweitig nicht genannt': 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen im Gesundheitswesen': 'Mittleres Management', 'Führungskräfte in der Beschaffung, Logistik und in verwandten Bereichen': 'Mittleres Management', 'Führungskräfte in der Erbringung von Dienstleistungen im Bereich Sport, Erholung und Kultur': 'Mittleres Management', 'Führungskräfte in Vertrieb und Marketing': 'Mittleres Management'}

# %%
top_management = {
'Angehörige gesetzgebender Körperschaften',
'Leitende Verwaltungsbedienstete',
'Leitende Bedienstete von Interessenorganisationen',
'Geschäftsführer und Vorstände',
}
# Convert to dictionary with the same value for all keys
top_management = {key: "Top Management" for key in top_management}

# %%
all_dfs = utils.build_data_frames()
# Out:
# /Users/leonardhaas/code/streamlit/data/raw_data/Zensus22_Sonderauswertung_Haas.xlsx

# %%
berufs_gattungen_4 = all_dfs['Berufsgattung (4-St.)']

# %%
# List of dictionaries to map
dict_list = [dienstleistungsarbeiter, industriearbeiter, hochspezialisiertebeschäftigte, 
             anleitender_beschäftigter, middle_management, top_management]

# Initialize 'modifiziert_livingstone' column with the first mapping
berufs_gattungen_4['modifiziert_livingstone'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[0])

# Sequentially map using the next dictionaries, filling missing values
for i in range(1, len(dict_list)):
    berufs_gattungen_4['modifiziert_livingstone'] = berufs_gattungen_4['Bezeichnung'].map(dict_list[i]).fillna(berufs_gattungen_4['modifiziert_livingstone'])

# Optional: You can print the resulting DataFrame to verify the final result
print(berufs_gattungen_4)
# Out:
#     ISCO-Code                                        Bezeichnung  Insgesamt  \
# 1        0110               Offiziere in regulären Streitkräften      22030
# 2        0210         Unteroffiziere in regulären Streitkräften       22020
# 3        0310  Angehörige der regulären Streitkräfte in sonst...     107160
# 4        1111           Angehörige gesetzgebender Körperschaften       9740
# 5        1112                    Leitende Verwaltungsbedienstete      15660
# ..        ...                                                ...        ...
# 416      9613                 Straßenkehrer und verwandte Berufe       6760
# 417      9621           Boten, Paketauslieferer und Gepäckträger     157600
# 418      9622                               Gelegenheitsarbeiter        690
# 419      9623    Zählerableser, Automatenbefüller und -kassierer       9010
# 420      9629      Hilfsarbeitskräfte, anderweitig nicht genannt      74020
#
#       percent        modifiziert_livingstone
# 1    0.053675                            NaN
# 2    0.053650                            NaN
# 3    0.261089                            NaN
# 4    0.023731                 Top Management
# 5    0.038155                 Top Management
# ..        ...                            ...
# 416  0.016470  Dienstleistungsarbeiter*innen
# 417  0.383983  Dienstleistungsarbeiter*innen
# 418  0.001681  Dienstleistungsarbeiter*innen
# 419  0.021952  Dienstleistungsarbeiter*innen
# 420  0.180345  Dienstleistungsarbeiter*innen
#
# [420 rows x 5 columns]

# %%
berufs_gattungen_4.dtypes
# Out:
# ISCO-Code                   object
# Bezeichnung                 object
# Insgesamt                    int64
# percent                    float64
# modifiziert_livingstone     object
# dtype: object

# %%
berufs_gattungen_4=berufs_gattungen_4.replace('/','0')
berufs_gattungen_4['Insgesamt'] = berufs_gattungen_4['Insgesamt'].astype(int)
berufs_gattungen_4

# Define a mapping from the first digit of ISCO-Code to the German name of the major group
isco_major_groups = {
    '0': 'Streitkräfte',
    '1': 'Führungskräfte',
    '2': 'Akademische Berufe',
    '3': 'Techniker und gleichrangige nichttechnische Berufe',
    '4': 'Bürokräfte und verwandte Berufe',
    '5': 'Dienstleistungsberufe und Verkäufer',
    '6': 'Landwirtschaftliche Berufe',
    '7': 'Handwerks- und verwandte Berufe',
    '8': 'Bediener von Anlagen und Maschinen und Montageberufe',
    '9': 'Hilfsarbeitskräfte'
}

# Ensure 'ISCO-Code' is treated as a string and strip any leading/trailing spaces
berufs_gattungen_4['ISCO-Code'] = berufs_gattungen_4['ISCO-Code'].astype(str).str.strip()

# Create a new column 'major_group' based on the first digit of 'ISCO-Code'
berufs_gattungen_4['major_group'] = berufs_gattungen_4['ISCO-Code'].str[0].map(isco_major_groups)

# Display the updated DataFrame
berufs_gattungen_4.rename({'Bezeichnung':'Berufsgattung(ISCO-Stufe 4)','Insgesamt':'Anzahl'}, axis=1, inplace=True)

#berufs_gattungen_4.to_csv('../data/processed_data/fraktion_daten.csv')

berufs_gattungen_4['ISCO-Code'] = berufs_gattungen_4['ISCO-Code'].astype(int)

berufs_gattungen_4[['ISCO-Code','major_group','Berufsgattung(ISCO-Stufe 4)','modifiziert_livingstone']].to_csv('../data/processed_data/isco_livingstone.csv')

# %%
#TODO warum werden die nicht richtig gelesen
#berufs_gattungen_4[berufs_gattungen_4['fraktion'].isna()]['Berufsgattung(ISCO-Stufe 4)'].unique()

# %% [markdown]
# ### start plotting

# %%
total=41043450
# Define the desired order of 'fraktion'
fraktion_order = [
    "Top Management","Mittleres Management","Anleitender Beschäftigter",
    "Hochspezialisierte Beschäftigte", "Industriearbeiter", "Dienstleistungsarbeiter"
]

# Calculate the percentage and sort by the defined order
fraktion_percentage = (berufs_gattungen_4.groupby(['fraktion'])['Insgesamt'].sum() / total) * 100
fraktion_percentage = fraktion_percentage.reindex(fraktion_order)

# Display the result
print(fraktion_percentage)
#(berufs_gattungen_4.groupby(['fraktion'])['Insgesamt'].sum()/ total) * 100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 9
#       3 fraktion_order = [
#       4     "Top Management","Mittleres Management","Anleitender Beschäftigter",
#       5     "Hochspezialisierte Beschäftigte", "Industriearbeiter", "Dienstleistungsarbeiter"
#       6 ]
#       8 # Calculate the percentage and sort by the defined order
# ----> 9 fraktion_percentage = (berufs_gattungen_4.groupby(['fraktion'])['Insgesamt'].sum() / total) * 100
#      10 fraktion_percentage = fraktion_percentage.reindex(fraktion_order)
#      12 # Display the result
#
# File ~/code/streamlit/.venv/lib/python3.9/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~/code/streamlit/.venv/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/code/streamlit/.venv/lib/python3.9/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'fraktion'

# %%
import plotly.express as px

# Convert the fraktion_percentage series to a DataFrame for easier plotting
fraktion_percentage_df = fraktion_percentage.reset_index()

# Create the horizontal bar plot
fig = px.bar(
    fraktion_percentage_df,
    x='Insgesamt',
    y='fraktion',
    orientation='h',
    title='Klassenfraktionen nach Anteil an Erwerbstätigen Daten Zensus 2022',
    labels={'Insgesamt': 'Prozent(%)','fraktion':'Fraktion'},
    text='Insgesamt'  # Add text to show the count
)

# Update the layout to increase the left margin
fig.update_layout(
    margin=dict(l=220)  # Adjust the left margin as needed
)

# Update the text position and color
fig.update_traces(
    textposition='inside',  # Position the text outside the bar
    texttemplate='%{text:.2f}%',  # Format the text
    textfont=dict(color='white')  # Set the text color to white
)

# Show the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 import plotly.express as px
#       3 # Convert the fraktion_percentage series to a DataFrame for easier plotting
# ----> 4 fraktion_percentage_df = fraktion_percentage.reset_index()
#       6 # Create the horizontal bar plot
#       7 fig = px.bar(
#       8     fraktion_percentage_df,
#       9     x='Insgesamt',
#    (...)
#      14     text='Insgesamt'  # Add text to show the count
#      15 )
#
# NameError: name 'fraktion_percentage' is not defined

# %%
berufs_gattungen_4
# Define a mapping from the first digit of ISCO-Code to the German name of the major group
isco_major_groups = {
    '0': 'Streitkräfte',
    '1': 'Führungskräfte',
    '2': 'Akademische Berufe',
    '3': 'Techniker und gleichrangige nichttechnische Berufe',
    '4': 'Bürokräfte und verwandte Berufe',
    '5': 'Dienstleistungsberufe und Verkäufer',
    '6': 'Landwirtschaftliche Berufe',
    '7': 'Handwerks- und verwandte Berufe',
    '8': 'Bediener von Anlagen und Maschinen und Montageberufe',
    '9': 'Hilfsarbeitskräfte'
}

# Ensure 'ISCO-Code' is treated as a string and strip any leading/trailing spaces
berufs_gattungen_4['ISCO-Code'] = berufs_gattungen_4['ISCO-Code'].astype(str).str.strip()

# Create a new column 'major_group' based on the first digit of 'ISCO-Code'
berufs_gattungen_4['major_group'] = berufs_gattungen_4['ISCO-Code'].str[0].map(isco_major_groups)

# Display the updated DataFrame
berufs_gattungen_4.rename({'Bezeichnung':'Berufsgattung(ISCO-Stufe 4)'}, axis=1, inplace=True)
print(berufs_gattungen_4)
# Out:
#     ISCO-Code                        Berufsgattung(ISCO-Stufe 4)  Anzahl  \
# 1        0110               Offiziere in regulären Streitkräften   22030
# 2        0210         Unteroffiziere in regulären Streitkräften    22020
# 3        0310  Angehörige der regulären Streitkräfte in sonst...  107160
# 4        1111           Angehörige gesetzgebender Körperschaften    9740
# 5        1112                    Leitende Verwaltungsbedienstete   15660
# ..        ...                                                ...     ...
# 416      9613                 Straßenkehrer und verwandte Berufe    6760
# 417      9621           Boten, Paketauslieferer und Gepäckträger  157600
# 418      9622                               Gelegenheitsarbeiter     690
# 419      9623    Zählerableser, Automatenbefüller und -kassierer    9010
# 420      9629      Hilfsarbeitskräfte, anderweitig nicht genannt   74020
#
#       percent  modifiziert_livingstone         major_group
# 1    0.053675                      NaN        Streitkräfte
# 2    0.053650                      NaN        Streitkräfte
# 3    0.261089                      NaN        Streitkräfte
# 4    0.023731           Top Management      Führungskräfte
# 5    0.038155           Top Management      Führungskräfte
# ..        ...                      ...                 ...
# 416  0.016470  Dienstleistungsarbeiter  Hilfsarbeitskräfte
# 417  0.383983  Dienstleistungsarbeiter  Hilfsarbeitskräfte
# 418  0.001681  Dienstleistungsarbeiter  Hilfsarbeitskräfte
# 419  0.021952  Dienstleistungsarbeiter  Hilfsarbeitskräfte
# 420  0.180345  Dienstleistungsarbeiter  Hilfsarbeitskräfte
#
# [420 rows x 6 columns]

# %%
import plotly.express as px

# Custom colors for different categories
colors = [
    '#1D4E1F',  # Dark green - Military (distinct from the others)
    '#0A1F44',  # Dark navy blue - Managers (more distinct from the others)
    '#F5B461',  # Golden yellow - Professionals (brighter)
    '#00CED1',  # DarkTurquoise - Technicians (brighter for distinction)
    '#9B59B6',  # Medium purple - Clerical (distinct from light purple)
    '#FF6B6B',  # Coral red - Service workers
    '#4A90E2',  # Sky blue - Agricultural
    '#af005f',  # deep pink - Craft workers
    '#4B2F2F',  # dark brown - Plant operators (more distinct from yellow)
    '#F2C9B3'   # Soft peach - Elementary (lighter for distinction)
]

fraktion_order = [
   "Top Management", "Mittleres Management", "Anleitender Beschäftigter",
   "Klassisch selbständige Tätigkeit", "Staatsangestellte",
   "Hochspezialisierte Beschäftigte", "Industriearbeiter", "Dienstleistungsarbeiter"
]


# Create horizontal bar chart
fig = px.bar(
    berufs_gattungen_4,
    x="Insgesamt",
    y="fraktion",
    color='major_group',
    orientation='h',
    hover_data={
        'Berufsgattung(ISCO-Stufe 4)': True,
        'Insgesamt': True,
        'fraktion': False,
        'major_group': False
    },
    title='Klassenanalyse',
    color_discrete_sequence=colors
)

# Style the silces of the bars with black borders and slight transparency
fig.update_traces(
    marker=dict(line=dict(width=0.5, color='black')),
    opacity=0.8
)

# Configure layout (size, legend, margins)
fig.update_layout(
    height=600,
    width=1000,
    legend=dict(
        title="Hauptgruppen ISCO-Stufe 1",
        font=dict(size=10)
    ),
    yaxis=dict(
        title=None,
       categoryorder='array',
       categoryarray=fraktion_order
    ),
    margin=dict(l=200), #preventing yaxis label cut off
    xaxis=dict(title="Anzahl der Erwerbstätigen in Millionen")  # changes x-axis label
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 25
#      17 fraktion_order = [
#      18    "Top Management", "Mittleres Management", "Anleitender Beschäftigter",
#      19    "Klassisch selbständige Tätigkeit", "Staatsangestellte",
#      20    "Hochspezialisierte Beschäftigte", "Industriearbeiter", "Dienstleistungsarbeiter"
#      21 ]
#      24 # Create horizontal bar chart
# ---> 25 fig = px.bar(
#      26     berufs_gattungen_4,
#      27     x="Insgesamt",
#      28     y="fraktion",
#      29     color='major_group',
#      30     orientation='h',
#      31     hover_data={
#      32         'Berufsgattung(ISCO-Stufe 4)': True,
#      33         'Insgesamt': True,
#      34         'fraktion': False,
#      35         'major_group': False
#      36     },
#      37     title='Klassenanalyse',
#      38     color_discrete_sequence=colors
#      39 )
#      41 # Style the silces of the bars with black borders and slight transparency
#      42 fig.update_traces(
#      43     marker=dict(line=dict(width=0.5, color='black')),
#      44     opacity=0.8
#      45 )
#
# File ~/code/streamlit/.venv/lib/python3.9/site-packages/plotly/express/_chart_types.py:373, in bar(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, text, base, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, pattern_shape_sequence, pattern_shape_map, range_color, color_continuous_midpoint, opacity, orientation, barmode, log_x, log_y, range_x, range_y, text_auto, title, template, width, height)
#     325 def bar(
#     326     data_frame=None,
#     327     x=None,
#    (...)
#     367     height=None,
#     368 ) -> go.Figure:
#     369     """
#     370     In a bar plot, each row of `data_frame` is represented as a rectangular
#     371     mark.
#     372     """
# --> 373     return make_figure(
#     374         args=locals(),
#     375         constructor=go.Bar,
#     376         trace_patch=dict(textposition="auto"),
#     377         layout_patch=dict(barmode=barmode),
#     378     )
#
# File ~/code/streamlit/.venv/lib/python3.9/site-packages/plotly/express/_core.py:2117, in make_figure(args, constructor, trace_patch, layout_patch)
#    2114 layout_patch = layout_patch or {}
#    2115 apply_default_cascade(args)
# -> 2117 args = build_dataframe(args, constructor)
#    2118 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2119     args = process_dataframe_hierarchy(args)
#
# File ~/code/streamlit/.venv/lib/python3.9/site-packages/plotly/express/_core.py:1513, in build_dataframe(args, constructor)
#    1510     args["color"] = None
#    1511 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1513 df_output, wide_id_vars = process_args_into_dataframe(
#    1514     args, wide_mode, var_name, value_name
#    1515 )
#    1517 # now that `df_output` exists and `args` contains only references, we complete
#    1518 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1519 # df_output
#    1521 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/code/streamlit/.venv/lib/python3.9/site-packages/plotly/express/_core.py:1234, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1232         if argument == "index":
#    1233             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1234         raise ValueError(err_msg)
#    1235 elif length and len(df_input[argument]) != length:
#    1236     raise ValueError(
#    1237         "All arguments should have the same length. "
#    1238         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1245         )
#    1246     )
#
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['ISCO-Code', 'Berufsgattung(ISCO-Stufe 4)', 'Anzahl', 'percent', 'modifiziert_livingstone', 'major_group'] but received: Insgesamt

# %%
berufs_gattungen_4.query("fraktion=='Industriearbeiter'").sort_values(by="Insgesamt",ascending=False).head(20)
